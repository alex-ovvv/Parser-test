# %%
# %%time

#Задаем урл главной страницы категории
x = "https://gotovim-doma.ru/category/55-napitki?"

#вытаскиваем библиотеки
import requests, bs4, tqdm
from bs4 import BeautifulSoup
from tqdm import tqdm_notebook
import numpy as np
from functools import reduce

#вытаскиваем html-код главной страницы раздела
def get_html(url):
    r = requests.get(url)
    return r.text

ready_html = get_html(x)

#получаем общее число страниц категории
def get_total_category_pages(ready_html):
    soup = BeautifulSoup(ready_html, 'lxml')
    divs = soup.find('div', class_='pager')
    pages = divs.find('li', class_='last')
    xxx = str(pages).split(">")[2].split("<")[0]
    return int(xxx)
#print (get_total_category_pages(ready_html))

#получаем ссылки на все страницы категории
def main_salat(base_url):
    page_part = "page="
    total_pages = get_total_category_pages(ready_html)   
    urls = []
    for i in range (1, total_pages + 1):
        url_gen = base_url + page_part + str(i)
        urls.append(url_gen)
    return urls
category_pages_url = list(main_salat(x))
#(main_salat(x)) #- формат получения записи
#print (category_pages_url)

#получаем урлы конкретных рецептов с одной страницы категории
def get_recipes_links(url):   
    ready_html = get_html(url)
    soup = BeautifulSoup(ready_html, 'lxml')
    h4 = list(soup.find_all('h4'))
    links = []
    for i in h4:
        div = i.find('a').get('href')
        url = "https://gotovim-doma.ru" + div
        links.append(url)
    return links

list_of_list_recipes = list(map(get_recipes_links, category_pages_url))
#print (list_of_list_recipes)

#делаем один массив из массива массивов
l = list_of_list_recipes
list_of_recipes = reduce(lambda x,y: x+y,l)
#print (list_of_recipes)

#получаем список ссылок уникальный рецептов со всех страниц категории
#category_url = x
#all_recipes = []
#pages = main_salat(salat_url)
#for page in tqdm_notebook(pages):
    #recipes = get_recipes_links(page)
    #for recipe in recipes:
        #all_recipes.append(recipe)
        
uniq_rec = np.unique(list_of_recipes)
#print (uniq_rec)
#len(uniq_rec)
# Out:
# CPU times: user 1.03 s, sys: 113 ms, total: 1.14 s
# Wall time: 5.33 s

# %%
print (len(uniq_rec))
print (uniq_rec[1])
# Out:
# 164
# https://gotovim-doma.ru/recipe/1144-mors-iz-krasnoi-smorodiny

# %%
def export_recipes(url):
    s=requests.get(url)
    b=bs4.BeautifulSoup(s.text, "html.parser")
    p4=b.select('.recept-table')
    recipe1=p4[0].getText()

    from string import digits
    remove_digits = str.maketrans('', '', digits)
    res = recipe1.translate(remove_digits)
#print (res)

    res1 = res.replace("(по желанию)", "")
    
    res_list = res1.split("\n")
#print (res_list)
    black_list = ["укроп (или другая зелень)", "Для сметанного соуса с укропом и чесноком", 'полпучка', " ", " ч.л. (по вкусу)", '', " зубчик", " г", ' ст.л.', "- веточки", " полпучка", " по вкусу", " ст.л.", "  ( г)", " шт ( г)", " шт", ' я беру на глаз, так отщипну от кусочка дрожжей, примерно получается как горох', '- горсти', ' шарика', ' ст.л. (или по вкусу)', ' кружочка', '  г', ' пакетик ( г)', ' г (примерно)', ' кг', '  ст.л.', ' шт (больших)', 'по  ч.л.', ' ст.л. или корешок свежего', ' кофейные чашки (по  мл)', ' пакет', 'тоник (в идеале "белый" - schweppes, sprite, но подойдет также любая белая газированная вода)', '- ст.л.', '- ягоды', 'пол пучка ', 'для одного  мл мохито',', л + , л для ананаса', '- шт', 'пару веточек ', '- кусочка ', '- мл', 'щепотка ', ' л', 'На - стакана (в зависимости от размера стаканов)', '- г  (или по вкусу)', ', бутончика', 'вода кипяченная комнатной температуры', ', ч.л.', 'пучок эстрагона ', '-  гр.', ' кофейная чашечка', ' Гр', '- ,л ', 'хороший растворимый кофе', ', стакана', 'чеснок', '- гр.', 'сахар (*положите сразу в приготовленный кофе до того, как будете его остужать)', 'кипяток', 'г ', 'Для сиропа', '. л', ' г (~, стакана)', ' стаканов (+ еще немного (всего приблизительно пара литров)', 'по-вкусу ', ' г (в очищенном виде -  г)', 'На банку (меньше чем литровая, из-под шоколадной пасты " дней")', ' зерен', '/ шт', 'вода', 'капучино-шейк (на  порцию)', ', стакан', '- тонких пластинки','на одну порцию', 'Либо ягоды и фрукты', ' шт (или ананасовый сок  мл)', ' г ( пакетик)', '/ палочки', ' шт (или лайм -  шт. вкус будет совершенно другим)', '/ зубчика', '- стебля', ' u', '- г (- ст.л.)', 'Для коктейля', "изюм (для подачи, по желанию)", ' ст.л. (с горкой)',  '+ л', '-  ст.л.', ' чашки', 'по вкусу ', 'сахар по вкусу (можно и без сахара)', '- шт. ', ', ст.л.', ' частей', 'лёд', ' листов (крупных)', ' пачки по  мл', ' гр (или по вкусу)', ' пакетик', 'щепотка корицы по вкусу', ' кг (вес без косточек)','/-/ стакана', 'вода (кипячёная)', ', шт', 'терпение!', ' г (уже очищенная мякоть)', ', литра', ' ч.л. (или по вкусу)', 'корочки - фруктов (апельсины, мандарины, лимоны, грейпфруты)', 'лимоны с тонкой шкуркой (можно чередовать: лимон - апельсин, лимон - лайм, апельсин - грейпфрут)', 'лед (много)', 'клубника (замороженная) ', 'овсяные хлопья - - ст.ложки с небольшой горкой', ',  ст.л.', ', кг', '- палочки', ' палочки', ' ломтик', '- ч.л.', 'минеральная вода (холодная)', ' ст.л.( или по вкусу)','- ст.л.(по вкусу)', 'клубника, мята - для украшения', '- стеблей ', '- бутона', ' шт.', ' шт спелые или  очень большой', 'соль, сахар по вкусу', 'холодная не газированая вода', 'вода, молоко или сливки', 'вода кипяченая (очищенная)', ' см', ' ч.л.', 'половинка ', 'вода (для чая)', '- г', 'на  чашки', '  ст.л. с горкой (примерно  гр)', 'маленькая щепотка соли', '- листика', 'для миндального молока', ',- стакана', ' листиков', ' звездочки', 'арбуз, любой (можно и не сладкий, который кушать не очень хочется)', ". ч.л.", ' мл для спирта (или  мл для водки)', 'ананас для подачи', 'цедра и сок двух лимонов', ' пару кубиков', 'холодная вода', '-, г', 'Для смузи', ' звёздочек ', 'лавровых ', 'сахар (мелкий)', '/ ст.л.', 'на  л воды', ' пачки (х, л)', 'минеральная газированная вода', ' баночка', '. ст.л', '- шт (в зависимости от их размера)', 'кусочек в  см ', '- коробочек', 'вода (дополнительно, для растворения крахмала)', 'горсть миндальных орехов (не указываю точное колличество)', ' ломтей', ' банка ( мл)', '"чудо - молоко" шоколадное (я в молоко добавила  ст.л. какао)', ' (большой (примерно  гр)', ' палочка ', '-, литра', 'заварной чай', ' на кончике ножа', '*подробно см рецепт', '(сахар и ром можно добавлять по вкусу)', 'для ', ' листочков', '-, л', 'для тостов', ' мл. очищенного ', '. кг', 'пол-лимона', 'банка сгущенки', 'горячий кофе', ' долька', ', ч.л. (я использовала ванильный сахар)', 'для  литра мацуна', 'вода кипяченая', '- г (я добавляла коньяк  г) мне нравится нежный', 'холодное цельное молоко', ' стручок', 'ёмкость (например, банка)', 'небольшой кусочек имбиря (кто не любит имбирь, можно не доабвлять)', ' части', 'от половинки лимона', '*сахара можно добавлять и больше, т.к. получается не очень сладко', 'цедра половины лимона', 'пол ч.л. сушёного молотого имбиря (я заменила на кусочек свежего  см)', ' стакан', 'Для напитков', '- г ( добавляйте по вкусу)', ' на кончике чайной ложки', ' банка', 'сахар коричневый (не добавляла)', '/ ст', ' листьев', ' ч.л. с горкой (я сварила  г натурального крепкого кофе)', 'кубики льда (или можно использовать кубики замороженного молока)', 'несколько кубиков льда', 'соль', ' по вкусу (я не добавляла)', 'на  чайник , л -  порции', ' пачки (х г)', 'для тыквенного молока', ' ст.л. с горкой ( - г)', 'яблочный сок или молоко, чтобы разбавить смузи до нужной густоты', ' гр.', ' г для спирта (или  г для водки)', ' мл  + ещё примерно - мл (см.рецепт)', '  ч.л.', ' литр', 'лед', ' чашечки (или  ч. л. растворимого кофе)', ' стакана', 'вода холодная', ' несколько', 'колотый лед', 'кг шт', 'для ласси', 'сильногазированная питьевая вода (или содовая)', ' кусочек (примерно - см)', 'Для сахарного сиропа:', ' по вкусу и по желанию', '- шт (маленькие)', ' полстакана', '/ ч.л.', '- веточек ', 'традиционное соотношение чая и кофе в этом напитке', 'состав (на л)',' щепотка', ' ст.л. без горки', 'лимонная кислота на кончике ножа', ',- ч.л.', 'кубики льда', ' вариант клубничный ликер', 'вода (или фруктовые соки)', ' гр', ' Г', 'для  ', ', л', ' мл', '*с таким количеством крахмала кисель получается очень густой, если хотите более жидкий, то можно уме', 'на  - х литровую банку', ' бутылка', 'для напитка', 'вода питьевая', 'для морса', 'Для коктейля:', ' мл ', ' шт. ', 'Сахар (по вкусу)', ' мл (или водка -  мл)', 'вода для заваривания', 'шоколадное чудо-молоко (это какао уже разведеный, в пачках)', ' щепотка по желанию', 'для овсяного молока', ' литра', 'Для кваса', 'вода для разбавления (минеральная с газом или охлажденная кипяченая)', '-  шт', 'скорлупа кедровых орехов', 'для сервировки - киви, листья мяты', 'мед', '   ', '/ стакана', 'дюжина или около того маленьких листиков мяты (свежих)', 'по желанию ']
    l3 = [x for x in res_list if x not in black_list]
    #l1 = res_list
    #l2 = ["укроп (или другая зелень)", "Для сметанного соуса с укропом и чесноком", 'полпучка', " ", " ч.л. (по вкусу)", '', " зубчик", " г", ' ст.л.'
     #" по вкусу", "- веточки", " полпучка", " по вкусу", " ст.л.", "  ( г)", " шт ( г)", " шт"]

    #l3 = [x for x in l1 if x not in l2]
#print (l3)
    return l3

    #res_set = set(l3)
    #return (res_set)

list_of_list_ingr = list(map(export_recipes, uniq_rec))

# %%
#print (list_of_list_ingr)
l1 = list_of_list_ingr
list_of_ingr = reduce(lambda x,y: x+y,l1)
#print (list_of_ingr)
set_of_ingr = set(list_of_ingr)
print (set_of_ingr)
# Out:
# {'красная смородина (чистый вес ягод)', 'ягоды (у меня замороженные малина и клубника)', 'йогурт', 'корень имбиря', 'какао-порошок', 'горький или темный шоколад', 'сода ', 'яблок', 'корица молотая ', 'мёд', 'зелёные яблоки', 'цикорий молотый', 'Водка - об.%', 'сметана', 'кофе растворимsq (я варила кофе из молотых кофейных зерен)', 'джем низкокалорийный', 'Сок половины апельсина', 'хлеб ржаной', 'белое сухое вино (хорошее)', 'курага', 'сок гранатовый', 'ваниль', ' свёкла (средняя)', 'сахар коричневый (тростниковый) ', 'желток яичный', 'горошины чёрного перца', 'банан (очень спелый)', 'лимоны (крупные)', 'сливки  %', 'гвоздика', 'шоколад', 'вода ', 'крепкий холодный кофе', 'апельсины', 'персик греческий', 'сахар или мёд', 'свежий тархун (эстрагон)', 'кардамон зеленый', 'клубника (чем вкуснее клубника - тем вкуснее десерт)', 'пол горсти изюма (лучше светлого)', 'арбуз очищенный ', 'звёздочки бадьяна', 'кардамон', 'Мятно-овощной ласси', 'дрожжи сухие', 'помидор', 'ликер kahlua (или другой кофейный ликер)', 'сок половинки лайма', 'вода минеральная', 'семена половины стручка ванили', 'душистый перец', 'цикорий', ' вариант кремово - клубничный ликер', 'тыква', 'сливки для взбивания % (охлажденные)', 'корица ', 'фруктовое ассорти (клубника, апельсин, груша, ананас)', 'огурец', 'закваска (ржаная или пшеничная) либо пол ст.л. свежих дрожжей', 'яблоки', 'арахисовая паста', 'Просекко (или ваше любимое игристое вино)', 'лед толченый ', 'кефир %', 'сахарный сироп (можно заменить  чайными ложками сахара)', 'сок  лимона', 'тыквенные семечки', 'коньяк (по-желанию)', 'зеленый чай без вкусовых добавок (у меня въетнамский лотосовый чай)', 'ваниль, соль', 'сахар коричневый', 'спирт (или водка)', 'бадьян', 'ваниль ', 'сгущённое молоко', 'чай красный', 'молоко (лучше не обезжиренное)', 'вода розовая', 'молоко или нежирные сливки', 'коньяк или другой качественный спиртной напиток', 'тертый имбирь', 'молоко (количество молока зависит от чашки, в которой будете подавать кофе)', 'сливы', 'темный ром', 'холодный приготовленный кофе', 'мед ', 'Свекольный ласси', 'киви (у меня без)', 'петрушка (верхушки с листьями)', 'ягоды', 'ягоды (микс)', 'груши', 'водка', 'ряженка (йогурт)', 'клюква', 'вода газированная', 'сок лимонный', 'Дольки лимона', 'свежий ананас', 'сливочный ликер (bailey`s)', 'свежая вишня (с косточками)', 'сок  лимонов', 'ванильный сахар', 'мята свежая', 'корень имбиря (неочищенный)', 'хлеб', 'яйцо', 'лимон', 'жидкий мед или сахар', 'какао порошок*', 'яйцо (меня недавно угостили домашними яйцами, поэтому этот ингредиент я не побоялась положить)', 'коньяк или виски', 'спирт (я добавила  гр)', 'овес - зерна целые , не дробленные', 'сахар (добавить в кофе, когда будете варить)', 'Смородина черная (у меня замороженная)', 'чернослив вяленый', 'кофейный ликёр или ликёр "амаретто" ', 'Виноградные гребешки', 'сахар (лучше коричневый)', 'кофе натуральный', 'спирт %', 'ванилин', 'белый ром ', 'кофе молотый', 'овсяные хлопья', 'кефир, лучше обезжиренный', 'чёрный чай хорошего качества', 'настойка мяты перечной (покупается в аптеке)', 'лавровый лист', 'сахар желирующий', 'очищенный миндаль, изюм (для подачи, по желанию)', 'имбирь размером с пробку от вина', 'тёртый на мелкой тёрке свежий корень имбиря*', 'дрожжи (сухие)', 'пучок петрушки', 'Мёд', 'джем "Персик-манго" МахеевЪ', 'арахис', 'лимон ', 'сок примерно / лимона', 'бутылка сухого красного вина', 'клубника', 'сироп (фруктовый, ягодный, кофейный, шоколадный и т.п.)', 'несколько веточек мяты ', 'ликер baileys irish cream', 'лимон или лайм', 'корица', 'Клюквенный морс (готовый)', 'концентрированное молоко', 'лимон (небольшой )', 'чай черный', 'молоко сгущенное', 'цветки лаванды (свежие или сухие)', 'апельсин (вернее сок)', 'мука', 'мёд или сахар по вкусу', 'палочка корицы', 'мелисса', 'яйцо куриное', 'зелёный чай, желательно с мятой или бергамотом', 'сок апельсина+мандарина', 'грепфрут (можно и апельсин)', 'ванильное мороженое', 'Ананасовый ласси', ' кубика', 'ваниль натуральная ', 'мед по желанию ', ' ...

# %%
cool_words = ["сок", "кофе"]
list_of_ingr_un = list(set_of_ingr)
for i in range(len(list_of_ingr_un)):
    for word in cool_words:
        if word in list_of_ingr_un[i]:
            list_of_ingr_un[i] = word
            break

print (list_of_ingr_un)
# Out:
# ['красная смородина (чистый вес ягод)', 'ягоды (у меня замороженные малина и клубника)', 'йогурт', 'корень имбиря', 'какао-порошок', 'горький или темный шоколад', 'сода ', 'яблок', 'корица молотая ', 'мёд', 'зелёные яблоки', 'цикорий молотый', 'Водка - об.%', 'сметана', 'кофе', 'джем низкокалорийный', 'Сок половины апельсина', 'хлеб ржаной', 'белое сухое вино (хорошее)', 'курага', 'сок', 'ваниль', ' свёкла (средняя)', 'сахар коричневый (тростниковый) ', 'желток яичный', 'горошины чёрного перца', 'банан (очень спелый)', 'лимоны (крупные)', 'сливки  %', 'гвоздика', 'шоколад', 'вода ', 'кофе', 'апельсины', 'персик греческий', 'сахар или мёд', 'свежий тархун (эстрагон)', 'кардамон зеленый', 'клубника (чем вкуснее клубника - тем вкуснее десерт)', 'пол горсти изюма (лучше светлого)', 'арбуз очищенный ', 'звёздочки бадьяна', 'кардамон', 'Мятно-овощной ласси', 'дрожжи сухие', 'помидор', 'кофе', 'сок', 'вода минеральная', 'семена половины стручка ванили', 'душистый перец', 'цикорий', ' вариант кремово - клубничный ликер', 'тыква', 'сливки для взбивания % (охлажденные)', 'корица ', 'фруктовое ассорти (клубника, апельсин, груша, ананас)', 'огурец', 'закваска (ржаная или пшеничная) либо пол ст.л. свежих дрожжей', 'яблоки', 'арахисовая паста', 'Просекко (или ваше любимое игристое вино)', 'лед толченый ', 'кефир %', 'сахарный сироп (можно заменить  чайными ложками сахара)', 'сок', 'тыквенные семечки', 'коньяк (по-желанию)', 'зеленый чай без вкусовых добавок (у меня въетнамский лотосовый чай)', 'ваниль, соль', 'сахар коричневый', 'спирт (или водка)', 'бадьян', 'ваниль ', 'сгущённое молоко', 'чай красный', 'молоко (лучше не обезжиренное)', 'вода розовая', 'молоко или нежирные сливки', 'коньяк или другой качественный спиртной напиток', 'тертый имбирь', 'кофе', 'сливы', 'темный ром', 'кофе', 'мед ', 'Свекольный ласси', 'киви (у меня без)', 'петрушка (верхушки с листьями)', 'ягоды', 'ягоды (микс)', 'груши', 'водка', 'ряженка (йогурт)', 'клюква', 'вода газированная', 'сок', 'Дольки лимона', 'свежий ананас', 'сливочный ликер (bailey`s)', 'свежая вишня (с косточками)', 'сок', 'ванильный сахар', 'мята свежая', 'корень имбиря (неочищенный)', 'хлеб', 'яйцо', 'лимон', 'жидкий мед или сахар', 'какао порошок*', 'яйцо (меня недавно угостили домашними яйцами, поэтому этот ингредиент я не побоялась положить)', 'коньяк или виски', 'спирт (я добавила  гр)', 'овес - зерна целые , не дробленные', 'кофе', 'Смородина черная (у меня замороженная)', 'чернослив вяленый', 'кофе', 'Виноградные гребешки', 'сахар (лучше коричневый)', 'кофе', 'спирт %', 'ванилин', 'белый ром ', 'кофе', 'овсяные хлопья', 'кефир, лучше обезжиренный', 'чёрный чай хорошего качества', 'настойка мяты перечной (покупается в аптеке)', 'лавровый лист', 'сахар желирующий', 'очищенный миндаль, изюм (для подачи, по желанию)', 'имбирь размером с пробку от вина', 'тёртый на мелкой тёрке свежий корень имбиря*', 'дрожжи (сухие)', 'пучок петрушки', 'Мёд', 'джем "Персик-манго" МахеевЪ', 'арахис', 'лимон ', 'сок', 'бутылка сухого красного вина', 'клубника', 'кофе', 'несколько веточек мяты ', 'ликер baileys irish cream', 'лимон или лайм', 'корица', 'Клюквенный морс (готовый)', 'концентрированное молоко', 'лимон (небольшой )', 'чай черный', 'молоко сгущенное', 'цветки лаванды (свежие или сухие)', 'сок', 'мука', 'мёд или сахар по вкусу', 'палочка корицы', 'мелисса', 'яйцо куриное', 'зелёный чай, желательно с мятой или бергамотом', 'сок', 'грепфрут (можно и апельсин)', 'ванильное мороженое', 'Ананасовый ласси', ' кубика', 'ваниль натуральная ', 'мед по желанию ', 'сахар по вкусу', 'сахар ', 'сушёная клюква (я не использовала)', 'ягоды (свежие или замороженные)', 'пломбир', 'лимонная кислота', 'цедра', 'виски', 'персик', 'корень имбиря (тертый)', 'яблоки (кисло-сладкие)', 'кофе', 'груши спелые', 'Цитрусовый чай', 'ликер или сироп (у меня сироп замляничный)', 'мята', 'банан среднего размера', 'огурец, тщательно очищенный и тонко нарезанный кружочками', 'изюм ', 'водка (или домашний самогон хорошего качества)', ' ...

# %%
import re
strn = ["word hereword word", "there word"]
search = "word"
for i in strn:
    if re.match(r"\b") = True
    return True
print (re.match(r"\b" + search + r"\b", strn))
# Out:
#   File "<ipython-input-24-5396430db80a>", line 5
#     if re.match(r"\b") = True
#                        ^
# SyntaxError: invalid syntax

# %%
#получаем урлы конкретных рецептов с одной страницы категории
def get_recipes_links(url):
        ready_html = get_html(url)
        soup = BeautifulSoup(ready_html, 'lxml')
        h4 = soup.find_all('h4')
        h41 = list(h4)
        links = []
        #return h41
        for i in h41:
            div = i.find('a').get('href')
            url = "https://gotovim-doma.ru" + div
            links.append(url)
        return links   
#print(pages)
print (get_recipes_links("https://gotovim-doma.ru/category/36-vypechka"))
# Out:
# ['https://gotovim-doma.ru/recipe/2139-testo-dlya-pitstsy-odin-iz-variantov', 'https://gotovim-doma.ru/recipe/27-blinchiki', 'https://gotovim-doma.ru/recipe/5774-tort-ptichye-moloko', 'https://gotovim-doma.ru/recipe/1783-pyshnyye-oladushki-na-drozhzhakh', 'https://gotovim-doma.ru/recipe/2132-zavarnoye-drozhzhevoye-bezoparnoye-testo-dlya-pirozhkov', 'https://gotovim-doma.ru/recipe/2434-tort-vozdushnyy-snikers', 'https://gotovim-doma.ru/recipe/2455-zavarnyye-bliny-na-kefire', 'https://gotovim-doma.ru/recipe/3154-darnitskiy-khleb-na-zakvaske-bez-drozhzhey', 'https://gotovim-doma.ru/recipe/2136-pirozhki-kak-pukh', 'https://gotovim-doma.ru/recipe/55-sharlotka-s-yablokami', 'https://gotovim-doma.ru/recipe/2135-pirozhki-myagenkiye', 'https://gotovim-doma.ru/recipe/1000-tort-napoleon', 'https://gotovim-doma.ru/recipe/2063-flammkukhen-iz-elzassa-pirog-s-lukom-bekonom-i-syrom', 'https://gotovim-doma.ru/recipe/6135-legkiy-medovik-zhidkoye-testo', 'https://gotovim-doma.ru/recipe/3151-pirozhnoye-korzinochka', 'https://gotovim-doma.ru/recipe/3056-shokoladnyye-maffiny', 'https://gotovim-doma.ru/recipe/2853-bulochki-brioshi-s-kremom-patisyer', 'https://gotovim-doma.ru/recipe/463-tort-medovik', 'https://gotovim-doma.ru/recipe/3412-pirog-domashniy', 'https://gotovim-doma.ru/recipe/5766-osnovnoy-belkovyy-krem', 'https://gotovim-doma.ru/recipe/795-mannik', 'https://gotovim-doma.ru/recipe/1892-tartufo-bianco-tort-belyy-tryufel', 'https://gotovim-doma.ru/recipe/3266-domashniy-tonkiy-lavash-bez-drozhzhey', 'https://gotovim-doma.ru/recipe/2439-shokoladnyy-tort-markiz', 'https://gotovim-doma.ru/recipe/4571-pryaniki-medovyye-raspisnyye', 'https://gotovim-doma.ru/recipe/2402-tort-muss-tri-shokolada-ot-luki-montersino', 'https://gotovim-doma.ru/recipe/3070-rozhdestvenskoye-nemetskoye-pechenye-mini-stollen', 'https://gotovim-doma.ru/recipe/4162-tort-chernyy-rytsar-s-kremom-na-varenoy-sgushchenke', 'https://gotovim-doma.ru/recipe/114-biskvit-klassicheskii', 'https://gotovim-doma.ru/recipe/4339-keks-v-kruzhke']

# %%
def main_salat(base_url):
    page_part = "page="
    total_pages = get_total_category_pages(ready_html)   
    urls = []
    for i in range (1, total_pages + 1):
        url_gen = base_url + page_part + str(i)
        urls.append(url_gen)
    return urls
category_pages_url = list(main_salat(x))
#(main_salat(x)) #- формат получения записи

# %%
# ready_html = get_html("https://gotovim-doma.ru/category/17-salaty?p=1")

def get_recipes_links(url):
    
    ready_html = get_html(url)
    soup = BeautifulSoup(ready_html, 'lxml')
    h4 = soup.find_all('h4')
    h41 = list(h4)
    links = []
    
    for i in h41:
        div = i.find('a').get('href')
        url = "https://gotovim-doma.ru" + div
        links.append(url)
    return links

list_of_list_recipes = list(map(get_recipes_links, category_pages_url))
print (list_of_list_recipes)
# Out:
# [['https://gotovim-doma.ru/recipe/2139-testo-dlya-pitstsy-odin-iz-variantov', 'https://gotovim-doma.ru/recipe/27-blinchiki', 'https://gotovim-doma.ru/recipe/5774-tort-ptichye-moloko', 'https://gotovim-doma.ru/recipe/1783-pyshnyye-oladushki-na-drozhzhakh', 'https://gotovim-doma.ru/recipe/2132-zavarnoye-drozhzhevoye-bezoparnoye-testo-dlya-pirozhkov', 'https://gotovim-doma.ru/recipe/2434-tort-vozdushnyy-snikers', 'https://gotovim-doma.ru/recipe/2455-zavarnyye-bliny-na-kefire', 'https://gotovim-doma.ru/recipe/3154-darnitskiy-khleb-na-zakvaske-bez-drozhzhey', 'https://gotovim-doma.ru/recipe/2136-pirozhki-kak-pukh', 'https://gotovim-doma.ru/recipe/55-sharlotka-s-yablokami', 'https://gotovim-doma.ru/recipe/2135-pirozhki-myagenkiye', 'https://gotovim-doma.ru/recipe/1000-tort-napoleon', 'https://gotovim-doma.ru/recipe/2063-flammkukhen-iz-elzassa-pirog-s-lukom-bekonom-i-syrom', 'https://gotovim-doma.ru/recipe/6135-legkiy-medovik-zhidkoye-testo', 'https://gotovim-doma.ru/recipe/3151-pirozhnoye-korzinochka', 'https://gotovim-doma.ru/recipe/3056-shokoladnyye-maffiny', 'https://gotovim-doma.ru/recipe/2853-bulochki-brioshi-s-kremom-patisyer', 'https://gotovim-doma.ru/recipe/463-tort-medovik', 'https://gotovim-doma.ru/recipe/3412-pirog-domashniy', 'https://gotovim-doma.ru/recipe/5766-osnovnoy-belkovyy-krem', 'https://gotovim-doma.ru/recipe/795-mannik', 'https://gotovim-doma.ru/recipe/1892-tartufo-bianco-tort-belyy-tryufel', 'https://gotovim-doma.ru/recipe/3266-domashniy-tonkiy-lavash-bez-drozhzhey', 'https://gotovim-doma.ru/recipe/2439-shokoladnyy-tort-markiz', 'https://gotovim-doma.ru/recipe/4571-pryaniki-medovyye-raspisnyye', 'https://gotovim-doma.ru/recipe/2402-tort-muss-tri-shokolada-ot-luki-montersino', 'https://gotovim-doma.ru/recipe/3070-rozhdestvenskoye-nemetskoye-pechenye-mini-stollen', 'https://gotovim-doma.ru/recipe/4162-tort-chernyy-rytsar-s-kremom-na-varenoy-sgushchenke', 'https://gotovim-doma.ru/recipe/114-biskvit-klassicheskii', 'https://gotovim-doma.ru/recipe/4339-keks-v-kruzhke'], ['https://gotovim-doma.ru/recipe/2462-lenivyy-khachapuri', 'https://gotovim-doma.ru/recipe/1900-pirozhnyye-bankokko', 'https://gotovim-doma.ru/recipe/2454-pechenye-pesochnyy-brilliant', 'https://gotovim-doma.ru/recipe/3900-milashino-testo-super-ekspress', 'https://gotovim-doma.ru/recipe/2465-nemetskiye-bulochki-s-sekretom-laugenbrotchen', 'https://gotovim-doma.ru/recipe/2468-bombochki-ot-dzheymi-olivera', 'https://gotovim-doma.ru/recipe/3422-oladi-smeshat-no-ne-vzbaltyvat', 'https://gotovim-doma.ru/recipe/3129-umnoye-pirozhnoye', 'https://gotovim-doma.ru/recipe/804-tsvetaevskii-yablochnyi-pirog', 'https://gotovim-doma.ru/recipe/2064-derevenskiy-rzhanoy-khleb-na-drozhzhakh', 'https://gotovim-doma.ru/recipe/3099-sakharnyye-bulochki-s-medovoy-glazuryu-roule-au-miel', 'https://gotovim-doma.ru/recipe/969-krymskie-chebureki', 'https://gotovim-doma.ru/recipe/3427-khotkeyki-blinchiki', 'https://gotovim-doma.ru/recipe/1790-kruassany-na-zavtrak', 'https://gotovim-doma.ru/recipe/3441-legkiy-i-ochen-nezhnyy-paskhalnyy-kulich', 'https://gotovim-doma.ru/recipe/3418-ovsyanoblin-ili-ovsyanka-s-yaytsami-po-novomu', 'https://gotovim-doma.ru/recipe/1793-frantsuzskiy-kruchenyy-baget', 'https://gotovim-doma.ru/recipe/1936-domashnyaya-sgushchenka-za-15-minut', 'https://gotovim-doma.ru/recipe/3263-khrustyashchiye-multizernovyye-khlebtsy-s-semechkami', 'https://gotovim-doma.ru/recipe/2939-biskvitnoye-testo-ne-razdelyaya-yaytsa-s-dobavleniyem-kipyatka', 'https://gotovim-doma.ru/recipe/2467-tvorozhnyy-tort-slezy-angela', 'https://gotovim-doma.ru/recipe/3168-pirog-steganoye-odeyalo', 'https://gotovim-doma.ru/recipe/3090-vozdushnyye-maffiny-s-sukhofruktami', 'https://gotovim-doma.ru/recipe/3906-shokoladnyye-pirozhnyye-s-propitkoy', 'https://gotovim-doma.ru/recipe/3902-tort-spartak-na-medovike', 'https://gotovim-doma.ru/recipe/5188-tort-molochnaya-devochka', 'https://gotovim-doma.ru/recipe/1999-medovyye-keksy-yablochnyye-maffiny-i-yeshche-2-postnykh-retsepta', 'https://gotovim- ...

# %%
from functools import reduce #python 3

l = list_of_list_recipes
l = reduce(lambda x,y: x+y,l)
print (l)
# Out:
# ['https://gotovim-doma.ru/recipe/2139-testo-dlya-pitstsy-odin-iz-variantov', 'https://gotovim-doma.ru/recipe/27-blinchiki', 'https://gotovim-doma.ru/recipe/5774-tort-ptichye-moloko', 'https://gotovim-doma.ru/recipe/1783-pyshnyye-oladushki-na-drozhzhakh', 'https://gotovim-doma.ru/recipe/2132-zavarnoye-drozhzhevoye-bezoparnoye-testo-dlya-pirozhkov', 'https://gotovim-doma.ru/recipe/2434-tort-vozdushnyy-snikers', 'https://gotovim-doma.ru/recipe/2455-zavarnyye-bliny-na-kefire', 'https://gotovim-doma.ru/recipe/3154-darnitskiy-khleb-na-zakvaske-bez-drozhzhey', 'https://gotovim-doma.ru/recipe/2136-pirozhki-kak-pukh', 'https://gotovim-doma.ru/recipe/55-sharlotka-s-yablokami', 'https://gotovim-doma.ru/recipe/2135-pirozhki-myagenkiye', 'https://gotovim-doma.ru/recipe/1000-tort-napoleon', 'https://gotovim-doma.ru/recipe/2063-flammkukhen-iz-elzassa-pirog-s-lukom-bekonom-i-syrom', 'https://gotovim-doma.ru/recipe/6135-legkiy-medovik-zhidkoye-testo', 'https://gotovim-doma.ru/recipe/3151-pirozhnoye-korzinochka', 'https://gotovim-doma.ru/recipe/3056-shokoladnyye-maffiny', 'https://gotovim-doma.ru/recipe/2853-bulochki-brioshi-s-kremom-patisyer', 'https://gotovim-doma.ru/recipe/463-tort-medovik', 'https://gotovim-doma.ru/recipe/3412-pirog-domashniy', 'https://gotovim-doma.ru/recipe/5766-osnovnoy-belkovyy-krem', 'https://gotovim-doma.ru/recipe/795-mannik', 'https://gotovim-doma.ru/recipe/1892-tartufo-bianco-tort-belyy-tryufel', 'https://gotovim-doma.ru/recipe/3266-domashniy-tonkiy-lavash-bez-drozhzhey', 'https://gotovim-doma.ru/recipe/2439-shokoladnyy-tort-markiz', 'https://gotovim-doma.ru/recipe/4571-pryaniki-medovyye-raspisnyye', 'https://gotovim-doma.ru/recipe/2402-tort-muss-tri-shokolada-ot-luki-montersino', 'https://gotovim-doma.ru/recipe/3070-rozhdestvenskoye-nemetskoye-pechenye-mini-stollen', 'https://gotovim-doma.ru/recipe/4162-tort-chernyy-rytsar-s-kremom-na-varenoy-sgushchenke', 'https://gotovim-doma.ru/recipe/114-biskvit-klassicheskii', 'https://gotovim-doma.ru/recipe/4339-keks-v-kruzhke', 'https://gotovim-doma.ru/recipe/2462-lenivyy-khachapuri', 'https://gotovim-doma.ru/recipe/1900-pirozhnyye-bankokko', 'https://gotovim-doma.ru/recipe/2454-pechenye-pesochnyy-brilliant', 'https://gotovim-doma.ru/recipe/3900-milashino-testo-super-ekspress', 'https://gotovim-doma.ru/recipe/2465-nemetskiye-bulochki-s-sekretom-laugenbrotchen', 'https://gotovim-doma.ru/recipe/2468-bombochki-ot-dzheymi-olivera', 'https://gotovim-doma.ru/recipe/3422-oladi-smeshat-no-ne-vzbaltyvat', 'https://gotovim-doma.ru/recipe/3129-umnoye-pirozhnoye', 'https://gotovim-doma.ru/recipe/804-tsvetaevskii-yablochnyi-pirog', 'https://gotovim-doma.ru/recipe/2064-derevenskiy-rzhanoy-khleb-na-drozhzhakh', 'https://gotovim-doma.ru/recipe/3099-sakharnyye-bulochki-s-medovoy-glazuryu-roule-au-miel', 'https://gotovim-doma.ru/recipe/969-krymskie-chebureki', 'https://gotovim-doma.ru/recipe/3427-khotkeyki-blinchiki', 'https://gotovim-doma.ru/recipe/1790-kruassany-na-zavtrak', 'https://gotovim-doma.ru/recipe/3441-legkiy-i-ochen-nezhnyy-paskhalnyy-kulich', 'https://gotovim-doma.ru/recipe/3418-ovsyanoblin-ili-ovsyanka-s-yaytsami-po-novomu', 'https://gotovim-doma.ru/recipe/1793-frantsuzskiy-kruchenyy-baget', 'https://gotovim-doma.ru/recipe/1936-domashnyaya-sgushchenka-za-15-minut', 'https://gotovim-doma.ru/recipe/3263-khrustyashchiye-multizernovyye-khlebtsy-s-semechkami', 'https://gotovim-doma.ru/recipe/2939-biskvitnoye-testo-ne-razdelyaya-yaytsa-s-dobavleniyem-kipyatka', 'https://gotovim-doma.ru/recipe/2467-tvorozhnyy-tort-slezy-angela', 'https://gotovim-doma.ru/recipe/3168-pirog-steganoye-odeyalo', 'https://gotovim-doma.ru/recipe/3090-vozdushnyye-maffiny-s-sukhofruktami', 'https://gotovim-doma.ru/recipe/3906-shokoladnyye-pirozhnyye-s-propitkoy', 'https://gotovim-doma.ru/recipe/3902-tort-spartak-na-medovike', 'https://gotovim-doma.ru/recipe/5188-tort-molochnaya-devochka', 'https://gotovim-doma.ru/recipe/1999-medovyye-keksy-yablochnyye-maffiny-i-yeshche-2-postnykh-retsepta', 'https://gotovim-dom ...

# %%
uniq_rec = np.unique(l)
len(uniq_rec)
# Out:
# 3319

# %%
list1 = (1, 2, 3, 4,5,5,67)
def sq(x):
    return x**2
print (list(map(sq, list1)))
# Out:
# [1, 4, 9, 16, 25, 25, 4489]

# %%
def get_recipes_links(url):
    #all_links = []
    #for pages in category_pages_url:
        
    
    ready_html = get_html(url)
    soup = BeautifulSoup(ready_html, 'lxml')
    h4 = list(soup.find_all('h4'))
    links = []
    
    for i in h4:
        div = i.find('a').get('href')
        url = "https://gotovim-doma.ru" + div
        links.append(url)
    return links

print (get_recipes_links("https://gotovim-doma.ru/category/36-vypechka"))
# Out:
# ['https://gotovim-doma.ru/recipe/2139-testo-dlya-pitstsy-odin-iz-variantov', 'https://gotovim-doma.ru/recipe/27-blinchiki', 'https://gotovim-doma.ru/recipe/5774-tort-ptichye-moloko', 'https://gotovim-doma.ru/recipe/1783-pyshnyye-oladushki-na-drozhzhakh', 'https://gotovim-doma.ru/recipe/2132-zavarnoye-drozhzhevoye-bezoparnoye-testo-dlya-pirozhkov', 'https://gotovim-doma.ru/recipe/2434-tort-vozdushnyy-snikers', 'https://gotovim-doma.ru/recipe/2455-zavarnyye-bliny-na-kefire', 'https://gotovim-doma.ru/recipe/3154-darnitskiy-khleb-na-zakvaske-bez-drozhzhey', 'https://gotovim-doma.ru/recipe/2136-pirozhki-kak-pukh', 'https://gotovim-doma.ru/recipe/55-sharlotka-s-yablokami', 'https://gotovim-doma.ru/recipe/2135-pirozhki-myagenkiye', 'https://gotovim-doma.ru/recipe/1000-tort-napoleon', 'https://gotovim-doma.ru/recipe/2063-flammkukhen-iz-elzassa-pirog-s-lukom-bekonom-i-syrom', 'https://gotovim-doma.ru/recipe/6135-legkiy-medovik-zhidkoye-testo', 'https://gotovim-doma.ru/recipe/3151-pirozhnoye-korzinochka', 'https://gotovim-doma.ru/recipe/3056-shokoladnyye-maffiny', 'https://gotovim-doma.ru/recipe/2853-bulochki-brioshi-s-kremom-patisyer', 'https://gotovim-doma.ru/recipe/463-tort-medovik', 'https://gotovim-doma.ru/recipe/3412-pirog-domashniy', 'https://gotovim-doma.ru/recipe/5766-osnovnoy-belkovyy-krem', 'https://gotovim-doma.ru/recipe/795-mannik', 'https://gotovim-doma.ru/recipe/1892-tartufo-bianco-tort-belyy-tryufel', 'https://gotovim-doma.ru/recipe/3266-domashniy-tonkiy-lavash-bez-drozhzhey', 'https://gotovim-doma.ru/recipe/2439-shokoladnyy-tort-markiz', 'https://gotovim-doma.ru/recipe/4571-pryaniki-medovyye-raspisnyye', 'https://gotovim-doma.ru/recipe/2402-tort-muss-tri-shokolada-ot-luki-montersino', 'https://gotovim-doma.ru/recipe/3070-rozhdestvenskoye-nemetskoye-pechenye-mini-stollen', 'https://gotovim-doma.ru/recipe/4162-tort-chernyy-rytsar-s-kremom-na-varenoy-sgushchenke', 'https://gotovim-doma.ru/recipe/114-biskvit-klassicheskii', 'https://gotovim-doma.ru/recipe/4339-keks-v-kruzhke']

# %%
salat_url = 'https://gotovim-doma.ru/category/22-supy?'

all_recipes = []

pages = main_salat(salat_url)

for page in tqdm_notebook(pages):
    recipes = get_recipes_links(page)
    
    for recipe in recipes:
        all_recipes.append(recipe)
        
uniq_rec = np.unique(all_recipes)
# Out:
# HBox(children=(IntProgress(value=0, max=33), HTML(value='')))

# %%
import requests, bs4
for rec in uniq_rec:
    #s=requests.get('https://gotovim-doma.ru/recipe/9390-oladi-iz-kabachkov-s-fetoy-brynzoy-ili-tvorogom')
    b=bs4.BeautifulSoup(s.text, "html.parser")
    p4=b.select('.recept-table')
    recipe1=p4[0].getText()

    from string import digits
    remove_digits = str.maketrans('', '', digits)
    res = recipe1.translate(remove_digits)
    #print (res)

    res1 = res.replace("(по желанию)", "")

    res_list = res1.split("\n")
#print (res_list)

    l1 = res_list
    l2 = ["укроп (или другая зелень)", "Для сметанного соуса с укропом и чесноком", 'полпучка', " ", " ч.л. (по вкусу)", '', " зубчик", " г", ' ст.л.'
     " по вкусу", "- веточки", " полпучка", " по вкусу", " ст.л.", "  ( г)", " шт ( г)", " шт"]

    l3 = [x for x in l1 if x not in l2]
#print (l3)

    res_set = set(l3)
    print (res_set)
# Out:
# {'соль', 'сыр Фета или Брынза (можно заменить творогом)', 'свежемолотый перец', 'укроп', 'растительное масло для жарки', 'чеснок ', 'мука', 'кабачки молодые', 'сметана', 'сок лимона', 'яйца'}
# {'соль', 'сыр Фета или Брынза (можно заменить творогом)', 'свежемолотый перец', 'укроп', 'растительное масло для жарки', 'чеснок ', 'мука', 'кабачки молодые', 'сметана', 'сок лимона', 'яйца'}
# {'соль', 'сыр Фета или Брынза (можно заменить творогом)', 'свежемолотый перец', 'укроп', 'растительное масло для жарки', 'чеснок ', 'мука', 'кабачки молодые', 'сметана', 'сок лимона', 'яйца'}
# {'соль', 'сыр Фета или Брынза (можно заменить творогом)', 'свежемолотый перец', 'укроп', 'растительное масло для жарки', 'чеснок ', 'мука', 'кабачки молодые', 'сметана', 'сок лимона', 'яйца'}
# {'соль', 'сыр Фета или Брынза (можно заменить творогом)', 'свежемолотый перец', 'укроп', 'растительное масло для жарки', 'чеснок ', 'мука', 'кабачки молодые', 'сметана', 'сок лимона', 'яйца'}
# {'соль', 'сыр Фета или Брынза (можно заменить творогом)', 'свежемолотый перец', 'укроп', 'растительное масло для жарки', 'чеснок ', 'мука', 'кабачки молодые', 'сметана', 'сок лимона', 'яйца'}
# {'соль', 'сыр Фета или Брынза (можно заменить творогом)', 'свежемолотый перец', 'укроп', 'растительное масло для жарки', 'чеснок ', 'мука', 'кабачки молодые', 'сметана', 'сок лимона', 'яйца'}
# {'соль', 'сыр Фета или Брынза (можно заменить творогом)', 'свежемолотый перец', 'укроп', 'растительное масло для жарки', 'чеснок ', 'мука', 'кабачки молодые', 'сметана', 'сок лимона', 'яйца'}
# {'соль', 'сыр Фета или Брынза (можно заменить творогом)', 'свежемолотый перец', 'укроп', 'растительное масло для жарки', 'чеснок ', 'мука', 'кабачки молодые', 'сметана', 'сок лимона', 'яйца'}
# {'соль', 'сыр Фета или Брынза (можно заменить творогом)', 'свежемолотый перец', 'укроп', 'растительное масло для жарки', 'чеснок ', 'мука', 'кабачки молодые', 'сметана', 'сок лимона', 'яйца'}
# {'соль', 'сыр Фета или Брынза (можно заменить творогом)', 'свежемолотый перец', 'укроп', 'растительное масло для жарки', 'чеснок ', 'мука', 'кабачки молодые', 'сметана', 'сок лимона', 'яйца'}
# {'соль', 'сыр Фета или Брынза (можно заменить творогом)', 'свежемолотый перец', 'укроп', 'растительное масло для жарки', 'чеснок ', 'мука', 'кабачки молодые', 'сметана', 'сок лимона', 'яйца'}
# {'соль', 'сыр Фета или Брынза (можно заменить творогом)', 'свежемолотый перец', 'укроп', 'растительное масло для жарки', 'чеснок ', 'мука', 'кабачки молодые', 'сметана', 'сок лимона', 'яйца'}
# {'соль', 'сыр Фета или Брынза (можно заменить творогом)', 'свежемолотый перец', 'укроп', 'растительное масло для жарки', 'чеснок ', 'мука', 'кабачки молодые', 'сметана', 'сок лимона', 'яйца'}
# {'соль', 'сыр Фета или Брынза (можно заменить творогом)', 'свежемолотый перец', 'укроп', 'растительное масло для жарки', 'чеснок ', 'мука', 'кабачки молодые', 'сметана', 'сок лимона', 'яйца'}
# {'соль', 'сыр Фета или Брынза (можно заменить творогом)', 'свежемолотый перец', 'укроп', 'растительное масло для жарки', 'чеснок ', 'мука', 'кабачки молодые', 'сметана', 'сок лимона', 'яйца'}
# {'соль', 'сыр Фета или Брынза (можно заменить творогом)', 'свежемолотый перец', 'укроп', 'растительное масло для жарки', 'чеснок ', 'мука', 'кабачки молодые', 'сметана', 'сок лимона', 'яйца'}
# {'соль', 'сыр Фета или Брынза (можно заменить творогом)', 'свежемолотый перец', 'укроп', 'растительное масло для жарки', 'чеснок ', 'мука', 'кабачки молодые', 'сметана', 'сок лимона', 'яйца'}
# {'соль', 'сыр Фета или Брынза (можно заменить творогом)', 'свежемолотый перец', 'укроп', 'растительное масло для жарки', 'чеснок ', 'мука', 'кабачки молодые', 'сметана', 'сок лимона', 'яйца'}
# {'соль', 'сыр Фета или Брынза (можно заменить творогом)', 'свежемолотый перец', 'укроп', 'растительное масло для жарки', 'чеснок ', 'мука', 'кабачки молодые', 'сметана', 'сок лимона', 'яйца'}
# {'соль', 'сыр Фета или Брынза (можно заменить творогом)', 'свежемолотый перец', 'укроп', 'растительное масло для жарки', 'чеснок ', 'мука', 'кабачки молодые', 'сметана', 'сок лимона', 'яйца'}
# {'соль', 'сыр Фета или Брынза (можно заменить творогом)', 'свежемолотый перец', 'укроп', 'растительное масло для жарки', 'чеснок ', 'мука', 'кабачки молодые', 'сметана', 'сок лимона', 'яйца'}
# {'соль', 'сыр Фета или Брынза (можно заменить творогом)', 'свежемолотый перец', 'укроп', 'растительное масло для жарки', 'чеснок ', 'мука', 'кабачки молодые', 'сметана', 'сок лимона', 'яйца'}
# {'соль', 'сыр Фета или Брынза (можно заменить творогом)', 'свежемолотый перец', 'укроп', 'растительное масло для жарки', 'чеснок ', 'мука', 'кабачки молодые', 'сметана', 'сок лимона', 'яйца'}
# {'соль', 'сыр Фета или Брынза (можно заменить творогом)', 'свежемолотый перец', 'укроп', 'растительное масло для жарки', 'чеснок ', 'мука', 'кабачки молодые', 'сметана', 'сок лимона', 'яйца'}
# {'соль', 'сыр Фета или Брынза (можно заменить творогом)', 'свежемолотый перец', 'укроп', 'растительное масло для жарки', 'чеснок ', 'мука', 'кабачки молодые', 'сметана', 'сок лимона', 'яйца'}
# {'соль', 'сыр Фета или Брынза (можно заменить творогом)', 'свежемолотый перец', 'укроп', 'растительное масло для жарки', 'чеснок ', 'мука', 'кабачки молодые', 'сметана', 'сок лимона', 'яйца'}
# {'соль', 'сыр Фета или Брынза (можно заменить творогом)', 'свежемолотый перец', 'укроп', 'растительное масло для жарки', 'чеснок ', 'мука', 'кабачки молодые', 'сметана', 'сок лимона', 'яйца'}
# {'соль', 'сыр Фета или Брынза (можно заменить творогом)', 'свежемолотый перец', 'укроп', 'растительное масло для жарки', 'чеснок ', 'мука', 'кабачки молодые', 'сметана', 'сок лимона', 'яйца'}
# {'соль', 'сыр Фета или Брынза (можно заменить творогом)', 'свежемолотый перец', 'укроп', 'растительное масло для жарки', 'чеснок ', 'мука', 'кабачки молодые', 'сметана', 'сок лимона', 'яйца'}

# %%
from bs4 import BeautifulSoup
def get_html(url):
    r = requests.get(url)
    return r.text

ready_html = get_html("https://gotovim-doma.ru/category/17-salaty?")

#f3
def get_total_pages(ready_html):
    soup = BeautifulSoup(ready_html, 'lxml')
    divs = soup.find('div', class_='pager')
    pages = divs.find('li', class_='last')
    xxx = str(pages).split(">")[2].split("<")[0]
    return int(xxx)

print (get_total_pages(ready_html))
# Out:
# 33

# %%
def get_html(url):
    r = requests.get(url)
    return r.text

ready_html = get_html("https://gotovim-doma.ru/category/26-vtorye-blyuda?page=2")
print (ready_html)
# Out:
#     <!DOCTYPE html>
#     <html lang="ru">
#     <head>
#         <meta charset="utf-8" />
#         <!--[if lt IE 9]><script src="//cdn.jsdelivr.net/html5shiv/3.7.3/html5shiv.min.js"></script><![endif]-->
#         <!--[if lte IE 6 ]><script type="text/javascript">window.location.href="/css/ie6/index_ru.html";</script><![endif]-->
#
#         <link href='//fonts.googleapis.com/css?family=Open+Sans:400italic,700italic,700,300,400&subset=latin,cyrillic-ext' rel='stylesheet' type='text/css'>
#         <link href='//fonts.googleapis.com/css?family=Yeseva+One&subset=latin,latin-ext,cyrillic' rel='stylesheet' type='text/css'>
#         <link rel="apple-touch-icon" sizes="180x180" href="/img/favicon/apple-touch-icon.png">
#         <link rel="icon" type="image/png" sizes="32x32" href="/img/favicon/favicon-32x32.png">
#         <link rel="icon" type="image/png" sizes="16x16" href="/img/favicon/favicon-16x16.png">
#         <link rel="manifest" href="/manifest.json">
#         <link rel="mask-icon" href="/img/favicon/safari-pinned-tab.svg" color="#5bbad5">
#         <link rel="shortcut icon" href="/img/favicon/favicon.ico">
#         <meta name="apple-mobile-web-app-title" content="Готовим дома">
#         <meta name="application-name" content="Готовим дома">
#         <meta name="msapplication-config" content="/browserconfig.xml">
#         <meta name="theme-color" content="#ffffff">
#         <meta name="viewport" content="width=1100">
#         <meta name="p:domain_verify" content="4af3e9612d3f4b9db3eb4194c267ff96"/>
#         <meta name='yandex-verification' content='681e49644e4147c0' />
#                 <meta name="csrf-param" content="_csrf">
#     <meta name="csrf-token" content="SKo_P7h9FpTRGp26lqlnN3yJwxF-eSpixCW3acWIsign3WhL_EhO8Z5e6uLf3gIAFN6zUjRLYy--QeIv8uv6aw==">
#         <script type="application/ld+json">{"@context":"http://schema.org/","@type":"ItemList","itemListElement":[{"@type":"ListItem","position":1,"url":"https://gotovim-doma.ru/recipe/3059-tefteli-s-tykvoy"},{"@type":"ListItem","position":2,"url":"https://gotovim-doma.ru/recipe/863-kartofelnaya-zapekanka-s-myasom"},{"@type":"ListItem","position":3,"url":"https://gotovim-doma.ru/recipe/250-kartoshka-tushennaya-s-kuritsey"},{"@type":"ListItem","position":4,"url":"https://gotovim-doma.ru/recipe/2303-kuritsa-v-rozovom-souse"},{"@type":"ListItem","position":5,"url":"https://gotovim-doma.ru/recipe/4161-kolbasa-kurinaya-domashnyaya-bystrogo-prigotovleniya"},{"@type":"ListItem","position":6,"url":"https://gotovim-doma.ru/recipe/822-myaso-zapechennoe-s-gribami-i-kartofelem"},{"@type":"ListItem","position":7,"url":"https://gotovim-doma.ru/recipe/3575-kurinoye-koltso-kayf"},{"@type":"ListItem","position":8,"url":"https://gotovim-doma.ru/recipe/4248-shashlyk-v-dukhovke-na-lukovoy-podushke"},{"@type":"ListItem","position":9,"url":"https://gotovim-doma.ru/recipe/1169-idyealnyi-zapechenyi-kartofel-ot-dzh-olivera"},{"@type":"ListItem","position":10,"url":"https://gotovim-doma.ru/recipe/1105-svinina-zapechennaya-s-pomidorami"},{"@type":"ListItem","position":11,"url":"https://gotovim-doma.ru/recipe/3131-ragu-s-kartofelem-i-sosiskami"},{"@type":"ListItem","position":12,"url":"https://gotovim-doma.ru/recipe/3929-otbivnyye-iz-pecheni"},{"@type":"ListItem","position":13,"url":"https://gotovim-doma.ru/recipe/1868-myasnoye-ragu-kotoroye-gotovitsya-samo-po-sebe"},{"@type":"ListItem","position":14,"url":"https://gotovim-doma.ru/recipe/104-golubtsy-lenivye"},{"@type":"ListItem","position":15,"url":"https://gotovim-doma.ru/recipe/3271-kartofel-marinovannyy-i-zapechennyy-v-dukhovke-s-ovoshchami"},{"@type":"ListItem","position":16,"url":"https://gotovim-doma.ru/recipe/4127-shtrudeli-odin-iz-variantov"},{"@type":"ListItem","position":17,"url":"https://gotovim-doma.ru/recipe/4965-kurochka-v-syrnom-souse"},{"@type":"ListItem","position":18,"url":"https://gotovim-doma.ru/recipe/2438-sochnyye-krylyshki"},{"@type":"ListItem","position":19,"url":"https://gotovim-doma.ru/recipe/4952-universalnaya-kasha-na-skoruyu-ruku"},{"@type":"ListItem","position":20,"url":"https://gotovim-doma.ru/recipe/688-zapekanka-iz-kuritsy-s-kartofelem"},{"@type":"ListItem","position":21,"url":"https://gotovim-doma.ru/recipe/1037-grecheskaya-musaka"},{"@type":"ListItem","position":22,"url":"https://gotovim-doma.ru/recipe/4548-lazanya-po-retseptu-babushki"},{"@type":"ListItem","position":23,"url":"https://gotovim-doma.ru/recipe/4960-kabachki-tushenyye"},{"@type":"ListItem","position":24,"url":"https://gotovim-doma.ru/recipe/2506-tefteli-v-dukhovke"},{"@type":"ListItem","position":25,"url":"https://gotovim-doma.ru/recipe/4131-sposob-prigotovleniya-vkusnogo-otvarnogo-kurinogo-file"},{"@type":"ListItem","position":26,"url":"https://gotovim-doma.ru/recipe/916-kurinaya-grudka-zapechennaya-s-baklazhanami-i-pomidorami"},{"@type":"ListItem","position":27,"url":"https://gotovim-doma.ru/recipe/1095-vareniki-s-kartofelem-postnye"},{"@type":"ListItem","position":28,"url":"https://gotovim-doma.ru/recipe/4957-detskaya-mannaya-kasha-po-pokhlebkinu"},{"@type":"ListItem","position":29,"url":"https://gotovim-doma.ru/recipe/4936-perkelt"},{"@type":"ListItem","position":30,"url":"https://gotovim-doma.ru/recipe/2407-domashniye-kurinyye-sosiski"}]}</script>        <title>Вторые блюда - рецепты с фото на Готовим дома</title>
#         <meta name="description" content="Вторые блюда - рецепты с фото на Готовим дома">
# <link href="/css/style.css?v=1524401300" rel="stylesheet">
# <script src="//ajax.googleapis.com/ajax/libs/jquery/1.12.4/jquery.min.js"></script>
# <script src="//ajax.googleapis.com/ajax/libs/jqueryui/1.12.1/jquery-ui.min.js"></script>
# <script src="/js/jquery.all.min.js?v=1495318064"></script>
# <script src="/js/main.min.js?v=1511299175"></script>    </head>
#     <body class=""><script type="text/javascript">var gd=gd||{};gd._csrf="SKo_P7h9FpTRGp26lqlnN3yJwxF-eSpixCW3acWIsign3WhL_EhO8Z5e6uLf3gIAFN6zUjRLYy--QeIv8uv6aw==";
# var recaptchaOnloadCallback = function(){jQuery('.g-recaptcha').each(function(){var widget_id=grecaptcha.render(jQuery(this)[0],{'sitekey':jQuery(this).data('sitekey'),'callback':window[jQuery(this).data('callback')]});jQuery(this).parent().data('widget',widget_id);});};
# var recaptchaCallback_PopupForgotformRecaptcha = function(response){jQuery('#popup-forgotform-recaptcha').val(response);};
# var recaptchaExpiredCallback_PopupForgotformRecaptcha = function(){jQuery('#popup-forgotform-recaptcha').val('');};
# var recaptchaCallback_PopupSignupformRecaptcha = function(response){jQuery('#popup-signupform-recaptcha').val(response);};
# var recaptchaExpiredCallback_PopupSignupformRecaptcha = function(){jQuery('#popup-signupform-recaptcha').val('');};
# (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
# ga('create', 'UA-1788673-1', 'auto');
# ga('send', 'pageview');
#     (function (d, w, c) {
#         (w[c] = w[c] || []).push(function() {
#             try {
#                 w.yaCounter44591563 = new Ya.Metrika({
#                     id:44591563,
#                     clickmap:true,
#                     trackLinks:true,
#                     accurateTrackBounce:true,
#                     webvisor:true
#                 });
#             } catch(e) { }
#         });
#
#         var n = d.getElementsByTagName("script")[0],
#             s = d.createElement("script"),
#             f = function () { n.parentNode.insertBefore(s, n); };
#         s.type = "text/javascript";
#         s.async = true;
#         s.src = "https://cdn.jsdelivr.net/npm/yandex-metrica-watch/watch.js";
#
#         if (w.opera == "[object Opera]") {
#             d.addEventListener("DOMContentLoaded", f, false);
#         } else { f(); }
#     })(document, window, "yandex_metrika_callbacks");</script>        <div class="" >
#             <header>
#         <div class="wr">
#             <div class="logo"><a href="/"><img src="/img/cont/logo.png?2" alt="Готовим дома"></a></div>
#             <div class="head-cont">
#                 <div class="head-cont-t">
#                     <ul class="menu-top">
#                         <li><a href="/forum">Кулинарный форум</a></li>
#                         <!--<li><a href="/articles">Статьи</a></li>-->                        <li><a href="/users">Кулинары</a></li>                        <li><a href="/contests">Конкурсы</a></li>
#                     </ul>
#                     <div class="head-autorize">
#                         <a href="/recipe/create" class="autorize-lnk recipes-lnk">Добавить свой рецепт</a>
#                         <a href="#" class="autorize-lnk popup_open enter-lnk" rel="#entrance-popup">Войти</a>                    </div>
#                 </div>
#                 <div class="search">
#                     <form action="/search">
#                         <div class="search-button"><button type="submit">Найти</button></div>
#                         <div class="search-input" id="search-input"><input type="text" name="q" id="sitesearch" placeholder="Введите название блюда или ингредиента"></div>
#                     </form>
#                 </div>
#                 <table class="menu-recipes">
#                     <tr>
#                         <th><a href="/user/3/recipes" class="ga-event" data-galabel="olesya header">Рецепты от Олеси</a></th><td></td>
#                         <th><a href="/video">Видеорецепты</a></th><td></td>
#                         <th><a href="/cuisines">Кухни мира</a></th><td></td>
#                         <!--th><a href="#">Способ приготовления</a></th><td></td>
#                         <th><a href="#">Готовим по поводу</a></th><td></td-->
#                         <!--th><a href="/tag/dlya-detyei">Детская кухня</a></th><td></td-->
#                         <th><a href="/tag/postnyye">Постные рецепты</a></th><td></td>
#                         <!--<th><a href="/category/360-bliny">Блины на масленицу</a></th>-->
#                         <th><a href="/category/791-shashlyki">Шашлыки</a></th>
#                     </tr>
#                 </table>
#             </div>
#             <div class="clear"></div>
#             <table class="menu-main">
#                 <tr>
#                     <th>
#                         <a href="/category/1-zakuski">Закуски</a>
#                         <!--<ul class="main-submenu">
#                             <li class="main-submenu__item"><a href="#">Горячие</a></li>
#                             <li class="main-submenu__item"><a href="#">Из печени</a></li>
#                             <li class="main-submenu__item"><a href="#">Мясные</a></li>
#                             <li class="main-submenu__item"><a href="#">Из рыбы, морепродуктов</a></li>
#                             <li class="main-submenu__item"><a href="#">Из овощей, фруктов</a></li>
#                             <li class="main-submenu__item"><a href="#">С грибами</a></li>
#                             <li class="main-submenu__item"><a href="#">Паштеты и террины</a></li>
#                             <li class="main-submenu__item"><a href="#">Закусочные торты</a></li>
#                             <li class="main-submenu__item"><a href="#">Закуски в лаваше</a></li>
#                             <li class="main-submenu__item"><a href="#">Из сыра, творога</a></li>
#                             <li class="main-submenu__item"><a href="#">Профитроли, тарталетки</a></li>
#                             <li class="main-submenu__item"><a href="#">Холодец и заливное</a></li>
#                             <li class="main-submenu__item"><a href="#">Яйца фаршированные</a></li>
#                             <li class="main-submenu__item"><a href="#">Бутерброды</a></li>
#                         </ul>-->
#                     </th>
#                     <td></td>
#                     <th><a href="/category/17-salaty">Салаты</a></th><td></td>
#                     <th><a href="/category/22-supy">Супы</a></th><td></td>
#                     <th><a href="/category/26-vtorye-blyuda">Вторые блюда</a></th><td></td>
#                     <th><a href="/category/36-vypechka">Выпечка</a></th><td></td>
#                     <th><a href="/category/50-deserty">Десерты</a></th><td></td>
#                     <th><a href="/category/55-napitki">Напитки</a></th><td></td>
#                     <th><a href="/category/59-sousy-i-zapravki">Соусы</a></th><td></td>
#                     <th><a href="/category/68-zagotovki">Заготовки</a></th><td></td>
#                     <th><a href="/category/186-raznoye">Разное</a></th>
#                 </tr>
#             </table>
#         </div>
#     </header>
#     <div class="content">
#         <div class="wr">
#             <div class="left-column">
#     <div class="crubs"><a href="/">Главная</a> <em class="ico-crubs"></em> Вторые блюда</div>    <div class="razdel-main">
#     <div class="razdel-img">
#         <div class="razdel-img-right"></div>
#         <div class="razdel-name"><h1>Вторые блюда</h1></div>
#     </div>
#             <ul class="razdel-menu">
#                     <li>
#                 <a href="/category/27-blyuda-iz-myasa">
#                     Мясо</a>
#             </li>
#                     <li>
#                 <a href="/category/801-blyuda-iz-ptitsy">
#                     Птица</a>
#             </li>
#                     <li>
#                 <a href="/category/874-golubtsy">
#                     Голубцы</a>
#             </li>
#                     <li>
#                 <a href="/category/825-farshirovannyye-ovoshchi">
#                     Фаршированные овощи</a>
#             </li>
#                     <li>
#                 <a href="/category/181-vtoryye-blyuda-iz-farsha">
#                     Из фарша</a>
#             </li>
#                     <li>
#                 <a href="/category/201-domashnyaya-kolbasa">
#                     Домашняя колбаса</a>
#             </li>
#                     <li>
#                 <a href="/category/767-blyuda-iz-subproduktov">
#                     Субпродукты</a>
#             </li>
#                     <li>
#                 <a href="/category/29-rybnyye-blyuda">
#                     Рыба</a>
#             </li>
#                     <li>
#                 <a href="/category/84-blyuda-iz-moreproduktov">
#                     Морепродукты</a>
#             </li>
#                     <li>
#                 <a href="/category/30-blyuda-iz-ovoshchey">
#                     Овощи</a>
#             </li>
#                     <li>
#                 <a href="/category/790-plov">
#                     Плов</a>
#             </li>
#                     <li>
#                 <a href="/category/791-shashlyki">
#                     Шашлыки</a>
#             </li>
#                     <li>
#                 <a href="/category/235-vtoryye-blyuda-zapekanki">
#                     Запеканки</a>
#             </li>
#                     <li>
#                 <a href="/category/814-blyuda-iz-bobovykh">
#                     Бобовые</a>
#             </li>
#                     <li>
#                 <a href="/category/781-blyuda-iz-gribov">
#                     Грибы</a>
#             </li>
#                     <li>
#                 <a href="/category/32-kashi-garniry">
#                     Каши, гарниры</a>
#             </li>
#                     <li>
#                 <a href="/category/35-blyuda-v-gorshochkakh">
#                     В горшочках</a>
#             </li>
#                     <li>
#                 <a href="/category/306-pelmeni-khinkali-manty">
#                     Пельмени, хинкали, манты</a>
#             </li>
#                     <li>
#                 <a href="/category/307-vareniki">
#                     Вареники</a>
#             </li>
#                     <li>
#                 <a href="/category/309-ravioli">
#                     Равиоли</a>
#             </li>
#                     <li>
#                 <a href="/category/33-makarony-lazanya-i-dr-izdeliya">
#                     Макароны, лазанья и т.д.</a>
#             </li>
#                     <li>
#                 <a href="/category/179-nokki-kletski-galushki">
#                     Ньокки, клецки, галушки</a>
#             </li>
#                 </ul>
#         </div>
# <div class="row-span">
#     <div class="span-12">
#         <div class="baner"><ins class="adsbygoogle"
#      style="display:block"
#      data-ad-client="ca-pub-1341081803137561"
#      data-ad-slot="5146775359"
#      data-ad-format="auto"></ins></div>
#     </div>
# </div>
#     <div class="row-span">
#             <div class="span-4">
#             <div class="recept-item">
#                 <div class="recept-item-img"><a href="/recipe/3059-tefteli-s-tykvoy"><img src="/images/recipe/4/90/490bbf73abfd58644538293bb9993195_m.jpg" alt="Тефтели с тыквой"></a></div>
#                 <div class="recept-item-in">
#                     <em>Легкий</em>
# 							<span class="recept-info">
# 								<span>53 <em class="ico_heart"></em></span>
# 								<span>173 <em class="ico_star"></em></span>
# 								<span>240 <em class="ico_discussion"></em></span>
# 							</span>
#                     <h4><a href="/recipe/3059-tefteli-s-tykvoy">Тефтели с тыквой</a></h4>
#                     <a href="/user/20712" class="ava-name">
#                         <img src="/images/ava/6/04/20712_60.gif">oldeg                    </a>
#                 </div>
#             </div>
#         </div>
#                     <div class="span-4">
#             <div class="recept-item">
#                 <div class="recept-item-img"><a href="/recipe/863-kartofelnaya-zapekanka-s-myasom"><img src="/images/recipe/b/7b/b7bce9e33f39ba74de5a316ec3f7c0e8_m.jpg" alt="Картофельная запеканка с мясом"></a></div>
#                 <div class="recept-item-in">
#                     <em>Легкий</em>
# 							<span class="recept-info">
# 								<span>7 <em class="ico_heart"></em></span>
# 								<span>458 <em class="ico_star"></em></span>
# 								<span>151 <em class="ico_discussion"></em></span>
# 							</span>
#                     <h4><a href="/recipe/863-kartofelnaya-zapekanka-s-myasom">Картофельная запеканка с мясом</a></h4>
#                     <a href="/user/3" class="ava-name">
#                         <img src="/images/ava/1/82/3_60.jpg">Олеся                    </a>
#                 </div>
#             </div>
#         </div>
#                     <div class="span-4">
#             <div class="recept-item">
#                 <div class="recept-item-img"><a href="/recipe/250-kartoshka-tushennaya-s-kuritsey"><img src="/images/recipe/4/97/4974286d59e470b8af3bc41fcee0b77a_m.jpg" alt="Картошка, тушенная с курицей"></a></div>
#                 <div class="recept-item-in">
#                     <em>Легкий</em>
# 							<span class="recept-info">
# 								<span>8 <em class="ico_heart"></em></span>
# 								<span>432 <em class="ico_star"></em></span>
# 								<span>169 <em class="ico_discussion"></em></span>
# 							</span>
#                     <h4><a href="/recipe/250-kartoshka-tushennaya-s-kuritsey">Картошка, тушенная с курицей</a></h4>
#                     <a href="/user/3" class="ava-name">
#                         <img src="/images/ava/1/82/3_60.jpg">Олеся                    </a>
#                 </div>
#             </div>
#         </div>
#                     </div><div class="row-span">
#                     <div class="span-4">
#             <div class="recept-item">
#                 <div class="recept-item-img"><a href="/recipe/2303-kuritsa-v-rozovom-souse"><img src="/images/recipe/0/ef/0efc51e2e3c46a94fd1d11f14fb8c201_m.jpg" alt="Курица в розовом соусе"></a></div>
#                 <div class="recept-item-in">
#                     <em>Легкий</em>
# 							<span class="recept-info">
# 								<span>62 <em class="ico_heart"></em></span>
# 								<span>196 <em class="ico_star"></em></span>
# 								<span>185 <em class="ico_discussion"></em></span>
# 							</span>
#                     <h4><a href="/recipe/2303-kuritsa-v-rozovom-souse">Курица в розовом соусе</a></h4>
#                     <a href="/user/69515" class="ava-name">
#                         <img src="/images/ava/3/26/69515_60.jpg">DolceVita                    </a>
#                 </div>
#             </div>
#         </div>
#                     <div class="span-4">
#             <div class="recept-item">
#                 <div class="recept-item-img"><a href="/recipe/4161-kolbasa-kurinaya-domashnyaya-bystrogo-prigotovleniya"><img src="/images/recipe/e/63/e6358bdb678b1a9877cd7ca39a6fb829_m.jpg" alt="Колбаса куриная домашняя быстрого приготовления"></a></div>
#                 <div class="recept-item-in">
#                     <em>Легкий</em>
# 							<span class="recept-info">
# 								<span>70 <em class="ico_heart"></em></span>
# 								<span>314 <em class="ico_star"></em></span>
# 								<span>167 <em class="ico_discussion"></em></span>
# 							</span>
#                     <h4><a href="/recipe/4161-kolbasa-kurinaya-domashnyaya-bystrogo-prigotovleniya">Колбаса куриная домашняя быстрого приготовления</a></h4>
#                     <a href="/user/37630" class="ava-name">
#                         <img src="/images/ava/a/8e/37630_60.gif">whal                    </a>
#                 </div>
#             </div>
#         </div>
#                     <div class="span-4">
#             <div class="recept-item">
#                 <div class="recept-item-img"><a href="/recipe/822-myaso-zapechennoe-s-gribami-i-kartofelem"><img src="/images/recipe/d/20/d20d2f304f0c83425996772f03cede86_m.jpg" alt="Мясо, запеченное с грибами и картофелем"></a></div>
#                 <div class="recept-item-in">
#                     <em>Легкий</em>
# 							<span class="recept-info">
# 								<span>5 <em class="ico_heart"></em></span>
# 								<span>432 <em class="ico_star"></em></span>
# 								<span>125 <em class="ico_discussion"></em></span>
# 							</span>
#                     <h4><a href="/recipe/822-myaso-zapechennoe-s-gribami-i-kartofelem">Мясо, запеченное с грибами и картофелем</a></h4>
#                     <a href="/user/3" class="ava-name">
#                         <img src="/images/ava/1/82/3_60.jpg">Олеся                    </a>
#                 </div>
#             </div>
#         </div>
#                     </div><div class="row-span">
#                     <div class="span-4">
#             <div class="recept-item">
#                 <div class="recept-item-img"><a href="/recipe/3575-kurinoye-koltso-kayf"><img src="/images/recipe/c/61/c619f90a4302e5efc1e0b06c03b67674_m.jpg" alt="Куриное кольцо &quot;Кайф&quot;"></a></div>
#                 <div class="recept-item-in">
#                     <em>Легкий</em>
# 							<span class="recept-info">
# 								<span>68 <em class="ico_heart"></em></span>
# 								<span>331 <em class="ico_star"></em></span>
# 								<span>106 <em class="ico_discussion"></em></span>
# 							</span>
#                     <h4><a href="/recipe/3575-kurinoye-koltso-kayf">Куриное кольцо &quot;Кайф&quot;</a></h4>
#                     <a href="/user/35819" class="ava-name">
#                         <img src="/images/ava/5/25/35819_60.jpg">lanita69                    </a>
#                 </div>
#             </div>
#         </div>
#                     <div class="span-4">
#             <div class="recept-item">
#                 <div class="recept-item-img"><a href="/recipe/4248-shashlyk-v-dukhovke-na-lukovoy-podushke"><img src="/images/recipe/a/7e/a7e679644ba2e885c47aca6e70c96067_m.jpg" alt="Шашлык в духовке на &quot;луковой подушке&quot;"></a></div>
#                 <div class="recept-item-in">
#                     <em>Легкий</em>
# 							<span class="recept-info">
# 								<span>62 <em class="ico_heart"></em></span>
# 								<span>290 <em class="ico_star"></em></span>
# 								<span>155 <em class="ico_discussion"></em></span>
# 							</span>
#                     <h4><a href="/recipe/4248-shashlyk-v-dukhovke-na-lukovoy-podushke">Шашлык в духовке на &quot;луковой подушке&quot;</a></h4>
#                     <a href="/user/148651" class="ava-name">
#                         <img src="/images/ava/no_avatar.png">Викуся Кукуся                    </a>
#                 </div>
#             </div>
#         </div>
#                     <div class="span-4">
#             <div class="recept-item">
#                 <div class="recept-item-img"><a href="/recipe/1169-idyealnyi-zapechenyi-kartofel-ot-dzh-olivera"><img src="/images/recipe/8/8a/88ab60e1f000a35450b703f27a4790cd_m.jpg" alt="Идеальный запеченый картофель от Дж. Оливера"></a></div>
#                 <div class="recept-item-in">
#                     <em>Легкий</em>
# 							<span class="recept-info">
# 								<span>14 <em class="ico_heart"></em></span>
# 								<span>417 <em class="ico_star"></em></span>
# 								<span>40 <em class="ico_discussion"></em></span>
# 							</span>
#                     <h4><a href="/recipe/1169-idyealnyi-zapechenyi-kartofel-ot-dzh-olivera">Идеальный запеченый картофель от Дж. Оливера</a></h4>
#                     <a href="/user/3" class="ava-name">
#                         <img src="/images/ava/1/82/3_60.jpg">Олеся                    </a>
#                 </div>
#             </div>
#         </div>
#                     </div><div class="row-span">
#                     <div class="span-4">
#             <div class="recept-item">
#                 <div class="recept-item-img"><a href="/recipe/1105-svinina-zapechennaya-s-pomidorami"><img src="/images/recipe/d/c4/dc494609a4edf6174bac05e58fdfe95d_m.jpg" alt="Свинина, запеченная с помидорами"></a></div>
#                 <div class="recept-item-in">
#                     <em>Легкий</em>
# 							<span class="recept-info">
# 								<span>8 <em class="ico_heart"></em></span>
# 								<span>402 <em class="ico_star"></em></span>
# 								<span>20 <em class="ico_discussion"></em></span>
# 							</span>
#                     <h4><a href="/recipe/1105-svinina-zapechennaya-s-pomidorami">Свинина, запеченная с помидорами</a></h4>
#                     <a href="/user/3" class="ava-name">
#                         <img src="/images/ava/1/82/3_60.jpg">Олеся                    </a>
#                 </div>
#             </div>
#         </div>
#                     <div class="span-4">
#             <div class="recept-item">
#                 <div class="recept-item-img"><a href="/recipe/3131-ragu-s-kartofelem-i-sosiskami"><img src="/images/recipe/9/2a/92a9134b5f26dd7803141c10c81ffd7a_m.jpg" alt="Рагу с картофелем и сосисками"></a></div>
#                 <div class="recept-item-in">
#                     <em>Легкий</em>
# 							<span class="recept-info">
# 								<span>49 <em class="ico_heart"></em></span>
# 								<span>182 <em class="ico_star"></em></span>
# 								<span>180 <em class="ico_discussion"></em></span>
# 							</span>
#                     <h4><a href="/recipe/3131-ragu-s-kartofelem-i-sosiskami">Рагу с картофелем и сосисками</a></h4>
#                     <a href="/user/20712" class="ava-name">
#                         <img src="/images/ava/6/04/20712_60.gif">oldeg                    </a>
#                 </div>
#             </div>
#         </div>
#                     <div class="span-4">
#             <div class="recept-item">
#                 <div class="recept-item-img"><a href="/recipe/3929-otbivnyye-iz-pecheni"><img src="/images/recipe/b/6f/b6fccefa72647f68a0c79a4bcf44df76_m.jpg" alt="Отбивные из печени"></a></div>
#                 <div class="recept-item-in">
#                     <em>Легкий</em>
# 							<span class="recept-info">
# 								<span>45 <em class="ico_heart"></em></span>
# 								<span>248 <em class="ico_star"></em></span>
# 								<span>168 <em class="ico_discussion"></em></span>
# 							</span>
#                     <h4><a href="/recipe/3929-otbivnyye-iz-pecheni">Отбивные из печени</a></h4>
#                     <a href="/user/15355" class="ava-name">
#                         <img src="/images/ava/d/77/15355_60.gif">tusya                    </a>
#                 </div>
#             </div>
#         </div>
#                     </div><div class="row-span">
#                     <div class="span-4">
#             <div class="recept-item">
#                 <div class="recept-item-img"><a href="/recipe/1868-myasnoye-ragu-kotoroye-gotovitsya-samo-po-sebe"><img src="/images/recipe/7/c6/7c6cdcd856d7b0921b298bd3da60edcb_m.jpg" alt="Мясное рагу, которое готовится само по себе"></a></div>
#                 <div class="recept-item-in">
#                     <em>Легкий</em>
# 							<span class="recept-info">
# 								<span>60 <em class="ico_heart"></em></span>
# 								<span>238 <em class="ico_star"></em></span>
# 								<span>147 <em class="ico_discussion"></em></span>
# 							</span>
#                     <h4><a href="/recipe/1868-myasnoye-ragu-kotoroye-gotovitsya-samo-po-sebe">Мясное рагу, которое готовится само по себе</a></h4>
#                     <a href="/user/69515" class="ava-name">
#                         <img src="/images/ava/3/26/69515_60.jpg">DolceVita                    </a>
#                 </div>
#             </div>
#         </div>
#                     <div class="span-4">
#             <div class="recept-item">
#                 <div class="recept-item-img"><a href="/recipe/104-golubtsy-lenivye"><img src="/images/recipe/d/0d/d0d283d8cbeeabe7671e0f2567bb2bb5_m.jpg" alt="Голубцы ленивые"></a></div>
#                 <div class="recept-item-in">
#                     <em>Легкий</em>
# 							<span class="recept-info">
# 								<span>8 <em class="ico_heart"></em></span>
# 								<span>384 <em class="ico_star"></em></span>
# 								<span>190 <em class="ico_discussion"></em></span>
# 							</span>
#                     <h4><a href="/recipe/104-golubtsy-lenivye">Голубцы ленивые</a></h4>
#                     <a href="/user/3" class="ava-name">
#                         <img src="/images/ava/1/82/3_60.jpg">Олеся                    </a>
#                 </div>
#             </div>
#         </div>
#                     <div class="span-4">
#             <div class="recept-item">
#                 <div class="recept-item-img"><a href="/recipe/3271-kartofel-marinovannyy-i-zapechennyy-v-dukhovke-s-ovoshchami"><img src="/images/recipe/f/82/f828aa413d66fdd66d8518960fdbdc5a_m.jpg" alt="Картофель маринованный и запеченный в духовке с овощами"></a></div>
#                 <div class="recept-item-in">
#                     <em>Легкий</em>
# 							<span class="recept-info">
# 								<span>70 <em class="ico_heart"></em></span>
# 								<span>265 <em class="ico_star"></em></span>
# 								<span>92 <em class="ico_discussion"></em></span>
# 							</span>
#                     <h4><a href="/recipe/3271-kartofel-marinovannyy-i-zapechennyy-v-dukhovke-s-ovoshchami">Картофель маринованный и запеченный в духовке с овощами</a></h4>
#                     <a href="/user/20712" class="ava-name">
#                         <img src="/images/ava/6/04/20712_60.gif">oldeg                    </a>
#                 </div>
#             </div>
#         </div>
#                     </div><div class="row-span">
#                     <div class="span-4">
#             <div class="recept-item">
#                 <div class="recept-item-img"><a href="/recipe/4127-shtrudeli-odin-iz-variantov"><img src="/images/recipe/0/db/0db66ae48c6999c2591baa2d8fe879e7_m.jpg" alt="&quot;Штрудели&quot; (один из вариантов)"></a></div>
#                 <div class="recept-item-in">
#                     <em>Легкий</em>
# 							<span class="recept-info">
# 								<span>42 <em class="ico_heart"></em></span>
# 								<span>214 <em class="ico_star"></em></span>
# 								<span>150 <em class="ico_discussion"></em></span>
# 							</span>
#                     <h4><a href="/recipe/4127-shtrudeli-odin-iz-variantov">&quot;Штрудели&quot; (один из вариантов)</a></h4>
#                     <a href="/user/32744" class="ava-name">
#                         <img src="/images/ava/1/d5/32744_60.jpg">admira                    </a>
#                 </div>
#             </div>
#         </div>
#                     <div class="span-4">
#             <div class="recept-item">
#                 <div class="recept-item-img"><a href="/recipe/4965-kurochka-v-syrnom-souse"><img src="/images/recipe/f/63/f639979cf797327443fccdc954ad4b99_m.jpg" alt="Курочка в сырном соусе"></a></div>
#                 <div class="recept-item-in">
#                     <em>Легкий</em>
# 							<span class="recept-info">
# 								<span>41 <em class="ico_heart"></em></span>
# 								<span>189 <em class="ico_star"></em></span>
# 								<span>155 <em class="ico_discussion"></em></span>
# 							</span>
#                     <h4><a href="/recipe/4965-kurochka-v-syrnom-souse">Курочка в сырном соусе</a></h4>
#                     <a href="/user/8815" class="ava-name">
#                         <img src="/images/ava/4/2a/8815_60.jpg">Kontik                    </a>
#                 </div>
#             </div>
#         </div>
#                     <div class="span-4">
#             <div class="recept-item">
#                 <div class="recept-item-img"><a href="/recipe/2438-sochnyye-krylyshki"><img src="/images/recipe/a/cf/acf55956f3dbed8fc0b7c31481f6f549_m.jpg" alt="Сочные крылышки"></a></div>
#                 <div class="recept-item-in">
#                     <em>Легкий</em>
# 							<span class="recept-info">
# 								<span>34 <em class="ico_heart"></em></span>
# 								<span>226 <em class="ico_star"></em></span>
# 								<span>123 <em class="ico_discussion"></em></span>
# 							</span>
#                     <h4><a href="/recipe/2438-sochnyye-krylyshki">Сочные крылышки</a></h4>
#                     <a href="/user/28813" class="ava-name">
#                         <img src="/images/ava/e/3f/28813_60.gif">noname                    </a>
#                 </div>
#             </div>
#         </div>
#                     </div><div class="row-span">
#                     <div class="span-4">
#             <div class="recept-item">
#                 <div class="recept-item-img"><a href="/recipe/4952-universalnaya-kasha-na-skoruyu-ruku"><img src="/images/recipe/3/19/319bd343432696bda59e5c65db7284fa_m.jpg" alt="Универсальная каша на скорую руку"></a></div>
#                 <div class="recept-item-in">
#                     <em>Легкий</em>
# 							<span class="recept-info">
# 								<span>17 <em class="ico_heart"></em></span>
# 								<span>69 <em class="ico_star"></em></span>
# 								<span>171 <em class="ico_discussion"></em></span>
# 							</span>
#                     <h4><a href="/recipe/4952-universalnaya-kasha-na-skoruyu-ruku">Универсальная каша на скорую руку</a></h4>
#                     <a href="/user/8815" class="ava-name">
#                         <img src="/images/ava/4/2a/8815_60.jpg">Kontik                    </a>
#                 </div>
#             </div>
#         </div>
#                     <div class="span-4">
#             <div class="recept-item">
#                 <div class="recept-item-img"><a href="/recipe/688-zapekanka-iz-kuritsy-s-kartofelem"><img src="/images/recipe/1/db/1db8488e9d694d07ce1c3365c9d1b87a_m.jpg" alt="Запеканка из курицы с картофелем"></a></div>
#                 <div class="recept-item-in">
#                     <em>Легкий</em>
# 							<span class="recept-info">
# 								<span>6 <em class="ico_heart"></em></span>
# 								<span>360 <em class="ico_star"></em></span>
# 								<span>114 <em class="ico_discussion"></em></span>
# 							</span>
#                     <h4><a href="/recipe/688-zapekanka-iz-kuritsy-s-kartofelem">Запеканка из курицы с картофелем</a></h4>
#                     <a href="/user/3" class="ava-name">
#                         <img src="/images/ava/1/82/3_60.jpg">Олеся                    </a>
#                 </div>
#             </div>
#         </div>
#                     <div class="span-4">
#             <div class="recept-item">
#                 <div class="recept-item-img"><a href="/recipe/1037-grecheskaya-musaka"><img src="/images/recipe/3/4b/34b85fa9809c218d98efc7aa6aa82344_m.jpg" alt="Греческая мусака"></a></div>
#                 <div class="recept-item-in">
#                     <em>Легкий</em>
# 							<span class="recept-info">
# 								<span>8 <em class="ico_heart"></em></span>
# 								<span>344 <em class="ico_star"></em></span>
# 								<span>97 <em class="ico_discussion"></em></span>
# 							</span>
#                     <h4><a href="/recipe/1037-grecheskaya-musaka">Греческая мусака</a></h4>
#                     <a href="/user/3" class="ava-name">
#                         <img src="/images/ava/1/82/3_60.jpg">Олеся                    </a>
#                 </div>
#             </div>
#         </div>
#                     </div><div class="row-span">
#                     <div class="span-4">
#             <div class="recept-item">
#                 <div class="recept-item-img"><a href="/recipe/4548-lazanya-po-retseptu-babushki"><img src="/images/recipe/c/35/c3589b3da51f593a6cdf3bf3028e7513_m.jpg" alt="Лазанья по рецепту бабушки"></a></div>
#                 <div class="recept-item-in">
#                     <em>Средний</em>
# 							<span class="recept-info">
# 								<span>47 <em class="ico_heart"></em></span>
# 								<span>219 <em class="ico_star"></em></span>
# 								<span>306 <em class="ico_discussion"></em></span>
# 							</span>
#                     <h4><a href="/recipe/4548-lazanya-po-retseptu-babushki">Лазанья по рецепту бабушки</a></h4>
#                     <a href="/user/15355" class="ava-name">
#                         <img src="/images/ava/d/77/15355_60.gif">tusya                    </a>
#                 </div>
#             </div>
#         </div>
#                     <div class="span-4">
#             <div class="recept-item">
#                 <div class="recept-item-img"><a href="/recipe/4960-kabachki-tushenyye"><img src="/images/recipe/9/31/931d35286260f68a4f1b6905e6227540_m.jpg" alt="Кабачки тушёные"></a></div>
#                 <div class="recept-item-in">
#                     <em>Легкий</em>
# 							<span class="recept-info">
# 								<span>38 <em class="ico_heart"></em></span>
# 								<span>164 <em class="ico_star"></em></span>
# 								<span>149 <em class="ico_discussion"></em></span>
# 							</span>
#                     <h4><a href="/recipe/4960-kabachki-tushenyye">Кабачки тушёные</a></h4>
#                     <a href="/user/46353" class="ava-name">
#                         <img src="/images/ava/2/b0/46353_60.jpg">Mariyana                    </a>
#                 </div>
#             </div>
#         </div>
#                     <div class="span-4">
#             <div class="recept-item">
#                 <div class="recept-item-img"><a href="/recipe/2506-tefteli-v-dukhovke"><img src="/images/recipe/e/4d/e4d79e571aedbf4971a08a063c4d57b9_m.jpg" alt="Тефтели в духовке"></a></div>
#                 <div class="recept-item-in">
#                     <em>Легкий</em>
# 							<span class="recept-info">
# 								<span>45 <em class="ico_heart"></em></span>
# 								<span>191 <em class="ico_star"></em></span>
# 								<span>189 <em class="ico_discussion"></em></span>
# 							</span>
#                     <h4><a href="/recipe/2506-tefteli-v-dukhovke">Тефтели в духовке</a></h4>
#                     <a href="/user/37630" class="ava-name">
#                         <img src="/images/ava/a/8e/37630_60.gif">whal                    </a>
#                 </div>
#             </div>
#         </div>
#                     </div><div class="row-span">
#                     <div class="span-4">
#             <div class="recept-item">
#                 <div class="recept-item-img"><a href="/recipe/4131-sposob-prigotovleniya-vkusnogo-otvarnogo-kurinogo-file"><img src="/images/recipe/a/08/a08a7653b7d10a01ec3afa921740d0f3_m.jpg" alt="Способ приготовления вкусного отварного куриного филе"></a></div>
#                 <div class="recept-item-in">
#                     <em>Легкий</em>
# 							<span class="recept-info">
# 								<span>66 <em class="ico_heart"></em></span>
# 								<span>266 <em class="ico_star"></em></span>
# 								<span>70 <em class="ico_discussion"></em></span>
# 							</span>
#                     <h4><a href="/recipe/4131-sposob-prigotovleniya-vkusnogo-otvarnogo-kurinogo-file">Способ приготовления вкусного отварного куриного филе</a></h4>
#                     <a href="/user/7949" class="ava-name">
#                         <img src="/images/ava/f/55/7949_60.gif">elena_110                    </a>
#                 </div>
#             </div>
#         </div>
#                     <div class="span-4">
#             <div class="recept-item">
#                 <div class="recept-item-img"><a href="/recipe/916-kurinaya-grudka-zapechennaya-s-baklazhanami-i-pomidorami"><img src="/images/recipe/3/96/3961fe27ad6468aa0948261c47a1eeac_m.jpg" alt="Куриная грудка, запеченная с баклажанами и помидорами"></a></div>
#                 <div class="recept-item-in">
#                     <em>Легкий</em>
# 							<span class="recept-info">
# 								<span>8 <em class="ico_heart"></em></span>
# 								<span>342 <em class="ico_star"></em></span>
# 								<span>219 <em class="ico_discussion"></em></span>
# 							</span>
#                     <h4><a href="/recipe/916-kurinaya-grudka-zapechennaya-s-baklazhanami-i-pomidorami">Куриная грудка, запеченная с баклажанами и помидорами</a></h4>
#                     <a href="/user/3" class="ava-name">
#                         <img src="/images/ava/1/82/3_60.jpg">Олеся                    </a>
#                 </div>
#             </div>
#         </div>
#                     <div class="span-4">
#             <div class="recept-item">
#                 <div class="recept-item-img"><a href="/recipe/1095-vareniki-s-kartofelem-postnye"><img src="/images/recipe/4/b6/4b64e942374c013a661f385ec8cc8680_m.jpg" alt="Вареники с картофелем (постные)"></a></div>
#                 <div class="recept-item-in">
#                     <em>Легкий</em>
# 							<span class="recept-info">
# 								<span>10 <em class="ico_heart"></em></span>
# 								<span>338 <em class="ico_star"></em></span>
# 								<span>52 <em class="ico_discussion"></em></span>
# 							</span>
#                     <h4><a href="/recipe/1095-vareniki-s-kartofelem-postnye">Вареники с картофелем (постные)</a></h4>
#                     <a href="/user/3" class="ava-name">
#                         <img src="/images/ava/1/82/3_60.jpg">Олеся                    </a>
#                 </div>
#             </div>
#         </div>
#                     </div><div class="row-span">
#                     <div class="span-4">
#             <div class="recept-item">
#                 <div class="recept-item-img"><a href="/recipe/4957-detskaya-mannaya-kasha-po-pokhlebkinu"><img src="/images/recipe/6/d6/6d6907961d71d1fd32f50da7e69adddc_m.jpg" alt="Детская манная каша по Похлебкину"></a></div>
#                 <div class="recept-item-in">
#                     <em>Легкий</em>
# 							<span class="recept-info">
# 								<span>36 <em class="ico_heart"></em></span>
# 								<span>118 <em class="ico_star"></em></span>
# 								<span>137 <em class="ico_discussion"></em></span>
# 							</span>
#                     <h4><a href="/recipe/4957-detskaya-mannaya-kasha-po-pokhlebkinu">Детская манная каша по Похлебкину</a></h4>
#                     <a href="/user/7596" class="ava-name">
#                         <img src="/images/ava/7/0b/7596_60.gif">Leksandra                    </a>
#                 </div>
#             </div>
#         </div>
#                     <div class="span-4">
#             <div class="recept-item">
#                 <div class="recept-item-img"><a href="/recipe/4936-perkelt"><img src="/images/recipe/1/91/191ef3191626a7a2088aad9a4788b9be_m.jpg" alt="Пёркёльт"></a></div>
#                 <div class="recept-item-in">
#                     <em>Легкий</em>
# 							<span class="recept-info">
# 								<span>52 <em class="ico_heart"></em></span>
# 								<span>221 <em class="ico_star"></em></span>
# 								<span>94 <em class="ico_discussion"></em></span>
# 							</span>
#                     <h4><a href="/recipe/4936-perkelt">Пёркёльт</a></h4>
#                     <a href="/user/5051" class="ava-name">
#                         <img src="/images/ava/a/40/5051_60.jpg">веруся                    </a>
#                 </div>
#             </div>
#         </div>
#                     <div class="span-4">
#             <div class="recept-item">
#                 <div class="recept-item-img"><a href="/recipe/2407-domashniye-kurinyye-sosiski"><img src="/images/recipe/c/d6/cd6acb87380bc42b0bf3ceb4855f4bfa_m.jpg" alt="Домашние куриные сосиски"></a></div>
#                 <div class="recept-item-in">
#                     <em>Средний</em>
# 							<span class="recept-info">
# 								<span>59 <em class="ico_heart"></em></span>
# 								<span>218 <em class="ico_star"></em></span>
# 								<span>92 <em class="ico_discussion"></em></span>
# 							</span>
#                     <h4><a href="/recipe/2407-domashniye-kurinyye-sosiski">Домашние куриные сосиски</a></h4>
#                     <a href="/user/69515" class="ava-name">
#                         <img src="/images/ava/3/26/69515_60.jpg">DolceVita                    </a>
#                 </div>
#             </div>
#         </div>
#                     </div><div class="row-span">
#                 </div><div class="row marg-b">
#     <h3>Поделись рецептами с друзьями!</h3>
#
#             <div data-background-alpha="0.0" data-buttons-color="#FFFFFF" data-counter-background-color="#ffffff" data-share-counter-size="12" data-top-button="false" data-share-counter-type="separate" data-share-style="1" data-mode="share" data-like-text-enable="false" data-hover-effect="scale" data-mobile-view="false" data-icon-color="#ffffff" data-orientation="horizontal" data-text-color="#000000" data-share-shape="round-rectangle" data-sn-ids="fb.vk.tw.ok.gp.ps.li." data-share-size="30" data-background-color="#ffffff" data-preview-mobile="false" data-mobile-sn-ids="fb.tw.wh.vb.ps." data-pid="1500538" data-counter-background-alpha="1.0" data-following-enable="false" data-exclude-show-more="true" data-selection-enable="false" class="uptolike-buttons" ></div>
#         </div>
# <div class="pager"><li class="pager-prev"><a href="/category/26-vtorye-blyuda" data-page="0">«&nbsp; Предыдущая</a></li><ul><li class="first"><a href="/category/26-vtorye-blyuda" data-page="0">1</a></li>
# <li class="active"><span>2</span></li>
# <li><a href="/category/26-vtorye-blyuda?page=3" data-page="2">3</a></li>
# <li><a href="/category/26-vtorye-blyuda?page=4" data-page="3">4</a></li>
# <li><a href="/category/26-vtorye-blyuda?page=5" data-page="4">5</a></li>
# <li><a href="/category/26-vtorye-blyuda?page=6" data-page="5">6</a></li>
# <li>...</li>
# <li class="last"><a href="/category/26-vtorye-blyuda?page=74" data-page="73">74</a></li></ul><li class="pager-next"><a href="/category/26-vtorye-blyuda?page=3" data-page="2">Следующая &nbsp;»</a></li></div><script type="text/javascript">
# $(document).ready(function(){
#     var descrMaxH = $('.razdel-detals').css('max-height'),
#         descrH = $('.razdel-detals').css('height');
#     $('.razdel-detals-lnk .close').click(function(){
#         $('.razdel-detals').animate({'height': descrH});
#         $('.razdel-detals').addClass('razdel-detals-fade');
#         $('.razdel-detals-lnk').addClass('active');
#         return false;
#     });
#     $('.razdel-detals-lnk .open').click(function(){
#         $('.razdel-detals').css('max-height', 'none');
#         $('.razdel-detals').css('height', 'auto');
#         $('.razdel-detals').removeClass('razdel-detals-fade');
#         $('.razdel-detals-lnk').removeClass('active');
#         return false;
#     });
# });
# </script>
# </div>
# <div class="right-column">
#     <a href="/recipe/create?category=26" class="add-recept">добавить рецепт</a>
#     <div id="adfox_150430373780388322" class="right-baner"></div>
#         <div id="adfox_149381225965831391"></div>
#
#             <div class="row-span marg-b">
# 				<div class="span-12 recept-box">
# 					<div class="recept-h">
# 						<div class="header-h2"><div class="ava"><a href="/user/3" class="ga-event" data-galabel="olesya random ava"><img src="/images/ava/1/82/3_60.jpg" alt=""></a></div> <a href="/user/3/recipes" class="ga-event" data-galabel="olesya random header">Рецепты от Олеси</a></div>
# 					</div>
# 					<a href="/recipe/602-kartofel-s-gribami-tushennyi-v-mikrovolnovke" class="recept-lnk">
#                     <img src="/images/recipe/5/cf/5cfcb7546de20c0a47659630e3e96992_m.jpg" alt=""><span>Картофель с грибами, тушенный в микроволновке</span></a>
# 				</div>
# 			</div>
#             <div class="box-social">
#         <ul class="social-tab">
#             <li class="soc-1 active"><a href="#">Instagram</a></li>
#             <li class="soc-2"><a href="#">Вконтакте</a></li>
#             <li class="soc-3"><a href="#">Facebook</a></li>
#         </ul>
#         <div class="social-cont">
#
# ...
#     <form id="popup-login-form" action="/login" method="post">
# <input type="hidden" name="_csrf" value="SKo_P7h9FpTRGp26lqlnN3yJwxF-eSpixCW3acWIsign3WhL_EhO8Z5e6uLf3gIAFN6zUjRLYy--QeIv8uv6aw==">    <table class="form-table">
#         <tr>
#             <th>Имя пользователя</th>
#             <td>
#                 <input type="text" id="popup-loginform-username" name="LoginForm[username]">
#                 <div class="error-message"></div>
#             </td>
#             <td class="td-comment"></td>
#         </tr>
#         <tr>
#             <th>Пароль</th>
#             <td>
#                 <input type="password" id="popup-loginform-password" name="LoginForm[password]">
#                 <div class="error-message"></div>
#             </td>
#             <td class="td-comment td-comment-pad"><a href="" class="popup_open" rel="#password-popup">Восстановить пароль</a></td>
#         </tr>
#         <tr>
#             <th></th>
#             <td class="td-text">
#                 <input id="popup-loginform-rememberme" type="checkbox" name="LoginForm[rememberMe]">
#                 <label for="popup-loginform-rememberme">Запомнить меня</label>
#             </td>
#         </tr>
#         <tr>
#             <th></th>
#             <td><button class="btn-style" name="popup-login-button">Войти</button></td>
#             <td class="td-comment"></td>
#         </tr>
#     </table>
#     </form>    </div>
#
# <div id="password-popup" class="popup popup-entrance password-popup">
#     <a href="" class="popup_close"></a>
#     <div class="popup-header">Восстановление пароля</div>
#     <div class="entrance-comment"><a href=""  class="popup_open" rel="#entrance-popup">Назад</a></div>
#     <form id="popup-forgot-password-form" action="/forgot" method="post">
# <input type="hidden" name="_csrf" value="SKo_P7h9FpTRGp26lqlnN3yJwxF-eSpixCW3acWIsign3WhL_EhO8Z5e6uLf3gIAFN6zUjRLYy--QeIv8uv6aw==">    <table class="form-table">
#         <tr>
#             <th>Эл. почта</th>
#             <td><div class="form-group field-forgotform-email required">
# <label class="control-label" for="forgotform-email"></label>
# <input type="text" id="forgotform-email" class="form-control" name="forgotForm[email]" aria-required="true">
#
# <div class="error-message"></div>
# </div><div class="error-message"></div></td>
#             <td class="td-comment td-comment-pad">Почта, которую вы указывали при регистрации</td>
#         </tr>
#         <tr>
#             <th></th>
#             <td><div class="form-group field-popup-forgotform-recaptcha">
#
# <input type="hidden" id="popup-forgotform-recaptcha" name="forgotForm[reCaptcha]"><div class="g-recaptcha" data-sitekey="6Ld7KQ0UAAAAADK0WLmhxsnRwq2U8-4D4lyTRK3P" data-callback="recaptchaCallback_PopupForgotformRecaptcha" data-expired-callback="recaptchaExpiredCallback_PopupForgotformRecaptcha"></div>
#
# <div class="error-message"></div>
# </div></td>
#             <td class="td-comment">Роботы не умеют готовить</td>
#         </tr>
#         <tr>
#             <th></th>
#             <td><button class="btn-style">Восстановить пароль</button></td>
#             <td class="td-comment"></td>
#         </tr>
#     </table>
#     </form></div>
#
# <div id="reg-ok-popup" class="popup popup-entrance">
#     <a href="" class="popup_close"></a>
#     <div class="popup-header">Спасибо за регистрацию</div>
#     <div class="popup-text">
#         <p>На указанную почту выслано письмо с ссылкой для подтверждения</p>
#     </div>
# </div>
#
# <div id="register-popup" class="popup popup-entrance">
#     <a href="" class="popup_close"></a>
#     <div class="popup-header">Регистрация</div>
#     <div class="entrance-comment"><a href="" class="popup_open" rel="#entrance-popup">Войдите</a> если есть аккаунт</div>
#     <form id="popup-signupform" action="/signup" method="post">
# <input type="hidden" name="_csrf" value="SKo_P7h9FpTRGp26lqlnN3yJwxF-eSpixCW3acWIsign3WhL_EhO8Z5e6uLf3gIAFN6zUjRLYy--QeIv8uv6aw==">    <table class="form-table">
#         <tr>
#             <th>Имя пользователя <span class="red">*</span></th>
#             <td>
#                 <div class="form-group field-popup-signupform-username required">
#                     <input type="text" id="popup-signupform-username" class="form-control" name="SignupForm[username]" aria-required="true">
#                     <div class="error-message"></div>
#                 </div>
#             </td>
#             <td class="td-comment">Ваш ник-нейм</td>
#         </tr>
#         <tr>
#             <th>Эл. почта <span class="red">*</span></th>
#             <td>
#                 <div class="form-group field-popup-signupform-email required">
#                     <input type="text" id="popup-signupform-email" class="form-control" name="SignupForm[email]" aria-required="true">
#                     <div class="error-message"></div>
#                 </div></td>
#             <td class="td-comment td-comment-pad">Ваш e-mail</td>
#         </tr>
#         <tr>
#             <th>Пароль <span class="red">*</span></th>
#             <td>
#                 <div class="form-group field-popup-signupform-password required">
#                     <input type="password" id="popup-signupform-password" class="form-control" name="SignupForm[password]" aria-required="true">
#                     <div class="error-message"></div>
#                 </div>
#             </td>
#             <td class="td-comment td-comment-pad">Должен быть длиной от 6 знаков</td>
#         </tr>
#         <tr>
#             <th>Подтвердите пароль <span class="red">*</span></th>
#             <td>
#                 <div class="form-group field-signupform-confirmpassword required">
#                     <input type="password" id="signupform-confirmpassword" class="form-control" name="SignupForm[confirmPassword]" aria-required="true">
#                     <div class="error-message"></div>
#                 </div>
#             </td>
#             <td class="td-comment td-comment-pad">Введите пароль еще раз</td>
#         </tr>
#         <tr>
#             <th></th>
#             <td>
#                 <div class="form-group field-popup-signupform-recaptcha">
#                     <input type="hidden" id="popup-signupform-recaptcha" name="SignupForm[reCaptcha]"><div class="g-recaptcha" data-sitekey="6Ld7KQ0UAAAAADK0WLmhxsnRwq2U8-4D4lyTRK3P" data-callback="recaptchaCallback_PopupSignupformRecaptcha" data-expired-callback="recaptchaExpiredCallback_PopupSignupformRecaptcha"></div>                    <div class="error-message"></div>
#                 </div>
#             </td>
#             <td class="td-comment td-comment-pad">Роботы не умеют готовить</td>
#         </tr>
#         <!--<tr>
#             <th></th>
#             <td colspan="2">
#                 <input type="checkbox" id="checkbox-reg"> <label for="checkbox-reg">Согласен с условиями пользования сайтом</label>
#             </td>
#         </tr>-->
#         <tr>
#             <th></th>
#             <td colspan="2"><button type="submit" class="btn-style" name="signup-button">Зарегистрироваться</button></td>
#         </tr>
#     </table>
#     </form></div>
#
# <div id="pass-ok-popup" class="popup popup-entrance pass-ok-popup">
#     <a href="" class="popup_close"></a>
#     <div class="popup-header">Восстановление пароля</div>
#     <div class="popup-text">
#         <p>Новый пароль выслан на указанную электронную почту.</p>
#     </div>
# </div>
# <script type="text/javascript">
#     $(document).ready(function () {
#         $('#popup-signupform').yiiActiveForm([{
#             "id": "signupform-username",
#             "name": "username",
#             "container": ".field-popup-signupform-username",
#             "input": "#popup-signupform-username",
#             "error": ".error-message",
#             "validate": function (attribute, value, messages, deferred, $form) {
#                 value = yii.validation.trim($form, attribute, []);
#                 yii.validation.required(value, messages, {"message": "Необходимо заполнить «Имя пользователя»"});
#                 yii.validation.string(value, messages, {
#                     "min": 2,
#                     "tooShort": "Значение «Имя пользователя» должно содержать минимум 2 символа",
#                     "max": 255,
#                     "tooLong": "Значение «Имя пользователя» должно содержать максимум 255 символов",
#                     "skipOnEmpty": 1
#                 });
#             }
#         }, {
#             "id": "signupform-email",
#             "name": "email",
#             "container": ".field-popup-signupform-email",
#             "input": "#popup-signupform-email",
#             "error": ".error-message",
#             "validate": function (attribute, value, messages, deferred, $form) {
#                 value = yii.validation.trim($form, attribute, []);
#                 yii.validation.required(value, messages, {"message": "Необходимо заполнить «Email»"});
#                 yii.validation.email(value, messages, {
#                     "pattern": /^[a-zA-Z0-9!#$%&'*+\/=?^_`{|}~-]+(?:\.[a-zA-Z0-9!#$%&'*+\/=?^_`{|}~-]+)*@(?:[a-zA-Z0-9](?:[a-zA-Z0-9-]*[a-zA-Z0-9])?\.)+[a-zA-Z0-9](?:[a-zA-Z0-9-]*[a-zA-Z0-9])?$/,
#                     "fullPattern": /^[^@]*<[a-zA-Z0-9!#$%&'*+\/=?^_`{|}~-]+(?:\.[a-zA-Z0-9!#$%&'*+\/=?^_`{|}~-]+)*@(?:[a-zA-Z0-9](?:[a-zA-Z0-9-]*[a-zA-Z0-9])?\.)+[a-zA-Z0-9](?:[a-zA-Z0-9-]*[a-zA-Z0-9])?>$/,
#                     "allowName": false,
#                     "message": "Значение «Email» не является правильным email адресом.",
#                     "enableIDN": false,
#                     "skipOnEmpty": 1
#                 });
#             }
#         }, {
#             "id": "signupform-password",
#             "name": "password",
#             "container": ".field-popup-signupform-password",
#             "input": "#popup-signupform-password",
#             "error": ".error-message",
#             "validate": function (attribute, value, messages, deferred, $form) {
#                 yii.validation.required(value, messages, {"message": "Укажите пароль"});
#                 yii.validation.string(value, messages, {
#                     "message": "Значение «Пароль» должно быть строкой.",
#                     "min": 6,
#                     "tooShort": "Значение «Пароль» должно содержать минимум 6 символов.",
#                     "skipOnEmpty": 1
#                 });
#             }
#         }, {
#             "id": "signupform-confirmpassword",
#             "name": "confirmPassword",
#             "container": ".field-signupform-confirmpassword",
#             "input": "#signupform-confirmpassword",
#             "error": ".error-message",
#             "validate": function (attribute, value, messages, deferred, $form) {
#                 yii.validation.required(value, messages, {"message": "Укажите пароль"});
#                 yii.validation.compare(value, messages, {
#                     "operator": "==",
#                     "type": "string",
#                     "compareAttribute": "popup-signupform-password",
#                     "skipOnEmpty": 1,
#                     "message": "Введенные пароли не совпадают"
#                 });
#             }
#         }, {
#             "id": "signupform-recaptcha",
#             "name": "reCaptcha",
#             "container": ".field-popup-signupform-recaptcha",
#             "input": "#popup-signupform-recaptcha",
#             "error": ".error-message",
#             "validate": function (attribute, value, messages, deferred, $form) {
#                 (function (messages, attribute) {
#                     var widget_id = $(attribute.container).data('widget');
#                     if (!grecaptcha.getResponse(widget_id)) {
#                         messages.push('Подтвердите, что вы не робот');
#                     }
#                 })(messages, attribute);
#             }
#         }], []);
#     });
# </script>
# <noscript><div><img src="//mytopf.com/counter?id=570109;js=na" style="border:0;position:absolute;left:-9999px;" alt="" /></div></noscript>
#     <script src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <script src="https://yastatic.net/pcode/adfox/loader.js"></script>
# <script src="//www.google.com/recaptcha/api.js?onload=recaptchaOnloadCallback&amp;render=explicit&amp;hl=ru" async defer></script>
# <script src="/assets/62a5b73a/yii.js?v=1512952982"></script>
# <script src="/assets/62a5b73a/yii.validation.js?v=1512952982"></script>
# <script src="/assets/62a5b73a/yii.activeForm.js?v=1512952982"></script>
# <script type="text/javascript">(function(w, d, n, s, t) {
#     w[n] = w[n] || [];
#     w[n].push(function() {
#         Ya.Context.AdvManager.render({
#             blockId: "R-A-45172-7",
#             renderTo: "yandex_rtb_R-A-45172-7",
#             horizontalAlign: true,
#             async: 1
#         });
#     });
#     t = d.getElementsByTagName("script")[0];
#     s = d.createElement("script");
#     s.type = "text/javascript";
#     s.src = "//an.yandex.ru/system/context.js";
#     s.async = true;
#     t.parentNode.insertBefore(s, t);
# })(this, this.document, "yandexContextAsyncCallbacks");
#         var _tmr = window._tmr || (window._tmr = []);
#         _tmr.push({id: "570109", type: "pageView", start: (new Date()).getTime()});
#         (function (d, w, id) {
#             if (d.getElementById(id)) return;
#             var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
#             ts.src = (d.location.protocol == "https:" ? "https:" : "http:") + "//mytopf.com/js/code-fb.js";
#             var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
#             if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
#         })(document, window, "topmailru-code");
# new Image().src = "//counter.yadro.ru/hit?r"+escape(document.referrer)+((typeof(screen)=="undefined")?"":";s"+screen.width+"*"+screen.height+"*"+(screen.colorDepth?screen.colorDepth:screen.pixelDepth))+";u"+escape(document.URL)+";"+Math.random();</script>
# <script type="text/javascript">jQuery(function ($) {
# (adsbygoogle = window.adsbygoogle || []).push({});
# (function(w,doc) {
# if (!w.__utlWdgt ) {
#     w.__utlWdgt = true;
#     var d = doc, s = d.createElement('script'), g = 'getElementsByTagName';
#     s.type = 'text/javascript'; s.charset='UTF-8'; s.async = true;
#     s.src = ('https:' == w.location.protocol ? 'https' : 'http')  + '://w.uptolike.com/widgets/v1/uptolike.js';
#     var h=d[g]('body')[0];
#     h.appendChild(s);
# }})(window,document);
# window.Ya.adfoxCode.create({
#     ownerId: 247118,
#     containerId: 'adfox_150430373780388322',
#     params: {
#         pp:'lcq', ps:'cfpp', p2:'fign'
#     }
# });
# window.Ya.adfoxCode.create({
#     ownerId: 247118,
#     containerId: 'adfox_149381225965831391',
#     params: {
#         pp:'g', ps:'cfpp', p2:'fign'
#     }
# });
# jQuery('#popup-forgot-password-form').yiiActiveForm([{"id":"forgotform-email","name":"email","container":".field-forgotform-email","input":"#forgotform-email","error":".error-message","validate":function (attribute, value, messages, deferred, $form) {value = yii.validation.trim($form, attribute, []);yii.validation.required(value, messages, {"message":"Необходимо заполнить «Email»."});yii.validation.email(value, messages, {"pattern":/^[a-zA-Z0-9!#$%&'*+\/=?^_`{|}~-]+(?:\.[a-zA-Z0-9!#$%&'*+\/=?^_`{|}~-]+)*@(?:[a-zA-Z0-9](?:[a-zA-Z0-9-]*[a-zA-Z0-9])?\.)+[a-zA-Z0-9](?:[a-zA-Z0-9-]*[a-zA-Z0-9])?$/,"fullPattern":/^[^@]*<[a-zA-Z0-9!#$%&'*+\/=?^_`{|}~-]+(?:\.[a-zA-Z0-9!#$%&'*+\/=?^_`{|}~-]+)*@(?:[a-zA-Z0-9](?:[a-zA-Z0-9-]*[a-zA-Z0-9])?\.)+[a-zA-Z0-9](?:[a-zA-Z0-9-]*[a-zA-Z0-9])?>$/,"allowName":false,"message":"Значение «Email» не является правильным email адресом.","enableIDN":false,"skipOnEmpty":1});}},{"id":"forgotform-recaptcha","name":"reCaptcha","container":".field-popup-forgotform-recaptcha","input":"#popup-forgotform-recaptcha","error":".error-message","validate":function (attribute, value, messages, deferred, $form) {(function(messages,attribute){var widget_id=jQuery(attribute.container).data('widget');if(!grecaptcha.getResponse(widget_id)){messages.push('Подтвердите, что вы не робот.');}})(messages,attribute);}}], []);
# });</script>    </div>
#     </body>
#     </html>

# %%
from tqdm import tqdm_notebook
